# %% [markdown]
# # Preparación de los datos

# %%
import os
import numpy as np
import pandas as pd
import chardet
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
from pmdarima.arima import auto_arima

from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing
import statsmodels.api as sm
import statsmodels.tsa.stattools as sts

if str(os.getcwdb()[-3:]).split("'")[1] != 'src':
    for _ in range(2):
        os.chdir(os.path.dirname(os.getcwdb()))

# %%
# Se comprueba el "encoding" de los csv mediante chardet
with open('data/raw/Anio2017.csv', 'rb') as f:
    result = chardet.detect(f.read())
    
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
# Se obtienen los datos de 2017
df_acoustics = pd.read_csv('data/raw/Anio2017.csv', encoding=result['encoding'], delimiter=';')

len(df_acoustics)
# Out:
# 370

# %%
# Se les concatenan los datos del resto de años de los csv
for year in range(2018, 2024):
    path = 'data/raw/Anio' + str(year) + '.csv'
    df = pd.read_csv(path, encoding=result['encoding'], delimiter=';')
    df_acoustics = pd.concat([df_acoustics, df])

len(df_acoustics)
# Out:
# 2292

# %%
# Se le concatenan, ahora, los datos del resto de años de los xls
# Se parte de 2012 porque en 2011 faltan 5 zonas
month_dict = {'ene': '01',
                'feb': '02',
                'mar': '03',
                'abr': '04',
                'may': '05',
                'jun': '06',
                'jul': '07',
                'ago': '08',
                'sep': '09',
                'oct': '10',
                'nov': '11',
                'dic': '12'
                }

skiprows = 3

for year in range(2012, 2017):
    path = 'data/raw/anio' + str(year) + '.xls'
    if year == 2015:
        month_dict_2015 = month_dict.copy()
        month_dict_2015.pop('jun')
        month_dict_2015.pop('jul')
        for sheet in range(10):
            df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
            df_xls['Fecha'] = list(month_dict_2015.keys())[sheet] + '-' + str(year)[2:]
            df_acoustics = pd.concat([df_acoustics, df_xls])
    else:
        if year == 2014:
            skiprows += 1
        for sheet in range(12):
            df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
            df_xls['Fecha'] = list(month_dict.keys())[sheet] + '-' + str(year)[2:]
            df_acoustics = pd.concat([df_acoustics, df_xls])

df_acoustics = df_acoustics.reset_index(drop=True)

len(df_acoustics)
# Out:
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:33: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:26: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# C:\Users\Roger\AppData\Local\Temp\ipykernel_1636\1082118438.py:26: FutureWarning: Defining usecols with out of bounds indices is deprecated and will raise a ParserError in a future version.
#   df_xls = pd.read_excel(path, sheet_name=sheet, skiprows=skiprows, usecols=range(1, 12))
# 4193

# %%
# Se elimina la columna "Unnamed"
df_acoustics = df_acoustics.drop(columns='Unnamed: 3')

df_acoustics.head()
# Out:
#     Fecha NMT           Situación    Ld    Le    Ln LAeq24 LAS01 LAS10 LAS50  \
# 0  ene-17   1  Paseo de Recoletos  69,1  69,2  66,5   68,2    74  71,3  65,8
# 1  ene-17   2            Carlos V  70,2  69,8  66,9   69,3  75,5  71,4  67,9
# 2  ene-17   3    Plaza del Carmen  67,7  60,9  62,8   65,8  75,4    66  58,5
# 3  ene-17   4     Plaza de España  65,9  65,9  62,4     65  72,7  67,4  63,5
# 4  ene-17   5    Barrio del Pilar  65,7  66,2  60,1   64,6  74,4    67  59,7
#
#   LAS90 LAS99 Nombre LAeq   L1  L10  L50  L90  L99
# 0  57,9    50    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  61,2  54,8    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  53,4  50,7    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  56,4  49,1    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  46,9  37,9    NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
# Se fusionan las columnas "Nombre" y "Situación", que son la misma cosa
df_acoustics['Situación'] = df_acoustics['Situación'].fillna(df_acoustics['Nombre'])
df_acoustics = df_acoustics.drop(columns='Nombre')

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4193 entries, 0 to 4192
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      4193 non-null   object
#  1   NMT        4112 non-null   object
#  2   Situación  4072 non-null   object
#  3   Ld         2912 non-null   object
#  4   Le         2912 non-null   object
#  5   Ln         2912 non-null   object
#  6   LAeq24     3344 non-null   object
#  7   LAS01      3342 non-null   object
#  8   LAS10      3342 non-null   object
#  9   LAS50      3342 non-null   object
#  10  LAS90      3342 non-null   object
#  11  LAS99      3342 non-null   object
#  12  LAeq       728 non-null    object
#  13  L1         728 non-null    object
#  14  L10        728 non-null    object
#  15  L50        728 non-null    object
#  16  L90        728 non-null    object
#  17  L99        728 non-null    object
# dtypes: object(18)
# memory usage: 589.8+ KB

# %%
# Se fusionan las demás columnas con datos comunes
for tuple in [('LAeq24', 'LAeq'), ('LAS01', 'L1'), ('LAS10', 'L10'), ('LAS50', 'L50'), ('LAS90', 'L90'), ('LAS99', 'L99')]:
    df_acoustics[tuple[0]] = df_acoustics[tuple[0]].fillna(df_acoustics[tuple[1]])

df_acoustics = df_acoustics.drop(columns=['LAeq', 'L1', 'L10', 'L50', 'L90', 'L99'])

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4193 entries, 0 to 4192
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      4193 non-null   object
#  1   NMT        4112 non-null   object
#  2   Situación  4072 non-null   object
#  3   Ld         2912 non-null   object
#  4   Le         2912 non-null   object
#  5   Ln         2912 non-null   object
#  6   LAeq24     4072 non-null   object
#  7   LAS01      4070 non-null   object
#  8   LAS10      4070 non-null   object
#  9   LAS50      4070 non-null   object
#  10  LAS90      4070 non-null   object
#  11  LAS99      4070 non-null   object
# dtypes: object(12)
# memory usage: 393.2+ KB

# %%
# Se borran las columnas con datos de mañana, día y noche, pues no existen para todos los años
df_acoustics = df_acoustics.drop(columns=['Ld', 'Le', 'Ln'])

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4193 entries, 0 to 4192
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      4193 non-null   object
#  1   NMT        4112 non-null   object
#  2   Situación  4072 non-null   object
#  3   LAeq24     4072 non-null   object
#  4   LAS01      4070 non-null   object
#  5   LAS10      4070 non-null   object
#  6   LAS50      4070 non-null   object
#  7   LAS90      4070 non-null   object
#  8   LAS99      4070 non-null   object
# dtypes: object(9)
# memory usage: 294.9+ KB

# %%
# Se buscan los valores donde las "LAS" son nulos pero "LAeq" no
df_acoustics[df_acoustics['LAS50'].isna() & df_acoustics['Situación'].notna()]
# Out:
#        Fecha NMT          Situación LAeq24 LAS01 LAS10 LAS50 LAS90 LAS99
# 4143  nov-16  16       Arturo Soria   61.5   NaN   NaN   NaN   NaN   NaN
# 4147  nov-16  20  Avda de Moratalaz   62.1   NaN   NaN   NaN   NaN   NaN

# %%
# Se busca el mes anterior a ese punto
df_acoustics[((df_acoustics['Situación'] == 'Arturo Soria') | (df_acoustics['Situación'] == 'Avda de Moratalaz'))
                & (df_acoustics['Fecha'] == 'oct-16')
              ]
# Out:
#        Fecha NMT          Situación LAeq24 LAS01 LAS10 LAS50 LAS90 LAS99
# 4112  oct-16  16       Arturo Soria   60.8  67.8  64.5  58.6  42.7  37.1
# 4116  oct-16  20  Avda de Moratalaz   61.6  70.8  64.2  58.0  44.8  36.1

# %%
# Se imputan esos nulos al mes anterior
for col, values in [('LAS01', [67.8, 70.8]), ('LAS10', [64.5, 64.2]), ('LAS50', [58.6, 58.0]), ('LAS90', [42.7, 44.8]), ('LAS99', [37.1, 36.1])]:
    fill_dict =  {4143: values[0], 4147: values[1]}
    df_acoustics[col] = df_acoustics[col].fillna(value=fill_dict)

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4193 entries, 0 to 4192
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      4193 non-null   object
#  1   NMT        4112 non-null   object
#  2   Situación  4072 non-null   object
#  3   LAeq24     4072 non-null   object
#  4   LAS01      4072 non-null   object
#  5   LAS10      4072 non-null   object
#  6   LAS50      4072 non-null   object
#  7   LAS90      4072 non-null   object
#  8   LAS99      4072 non-null   object
# dtypes: object(9)
# memory usage: 294.9+ KB

# %%
# Se borran los demás nulos, pues son errores de la conversion de los xls
# Todavía existen nulos, pero no son fallos de conversión y están en formato "string"
df_acoustics = df_acoustics.dropna()

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4072 entries, 0 to 4192
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha      4072 non-null   object
#  1   NMT        4072 non-null   object
#  2   Situación  4072 non-null   object
#  3   LAeq24     4072 non-null   object
#  4   LAS01      4072 non-null   object
#  5   LAS10      4072 non-null   object
#  6   LAS50      4072 non-null   object
#  7   LAS90      4072 non-null   object
#  8   LAS99      4072 non-null   object
# dtypes: object(9)
# memory usage: 318.1+ KB

# %%
# Se añaden los meses faltantes del año 15 con nulos. Se imputarán más adelante
for month in ['jun-15', 'jul-15']:
    df_summer_15 = df_acoustics[df_acoustics['Fecha'] == 'ago-15'].copy()
    df_summer_15[['LAeq24', 'LAS01', 'LAS10', 'LAS50', 'LAS90', 'LAS99', 'NMT']] = np.nan
    df_summer_15['Fecha'] = month
    df_acoustics = pd.concat([df_acoustics, df_summer_15])

# %%
# Se convierte la columna "Fecha" al formato "datetime" y se pasa al índice
df_acoustics['Fecha'] = df_acoustics['Fecha'].str.split('-').apply(lambda x: f'{month_dict[x[0]]}-{x[1]}')
df_acoustics['Fecha'] = pd.to_datetime(df_acoustics['Fecha'], format='%m-%y')

df_acoustics = df_acoustics.rename(columns={'Fecha': 'mes'})

df_acoustics = df_acoustics.set_index('mes')
df_acoustics = df_acoustics.sort_index()

df_acoustics.index
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-01', '2012-01-01', '2012-01-01',
#                '2012-01-01', '2012-01-01', '2012-01-01', '2012-01-01',
#                '2012-01-01', '2012-01-01',
#                ...
#                '2023-02-01', '2023-02-01', '2023-02-01', '2023-02-01',
#                '2023-02-01', '2023-02-01', '2023-02-01', '2023-02-01',
#                '2023-02-01', '2023-02-01'],
#               dtype='datetime64[ns]', name='mes', length=4134, freq=None)

# %%
# Se pasan a numéricos los no nulos de todas las columnas, y las "string" que representan los nulos se convierten en nulos reales
df_acoustics = df_acoustics.astype(str)

for col in df_acoustics.columns[2:]:
    df_acoustics[col] = df_acoustics[col].apply(lambda x: ''.join([number.replace(',', '.') if ',' in number else number for number in x]))
    df_acoustics[col] = df_acoustics[col].apply(lambda x: float(x) if x != 'N/D' else np.nan)

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4134 entries, 2012-01-01 to 2023-02-01
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   NMT        4134 non-null   object
#  1   Situación  4134 non-null   object
#  2   LAeq24     4019 non-null   float64
#  3   LAS01      4005 non-null   float64
#  4   LAS10      4005 non-null   float64
#  5   LAS50      4005 non-null   float64
#  6   LAS90      4005 non-null   float64
#  7   LAS99      4005 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 290.7+ KB

# %%
# Se cambian los nombres de las columnas para mayor claridad
df_acoustics = df_acoustics.rename(columns={'NMT': 'num_medidas',
                                          'Situación': 'zonas',
                                            'LAeq24': 'sonido_24_h',
                                            'LAS01': 'sonido_superado_1%',
                                            'LAS10': 'sonido_superado_10%',
                                            'LAS50': 'sonido_superado_50%',
                                            'LAS90': 'sonido_superado_90%',
                                            'LAS99': 'sonido_superado_99%'
                                            }
                                    )                   

df_acoustics.head()
# Out:
#            num_medidas                     zonas  sonido_24_h  \
# mes
# 2012-01-01           1        Paseo de Recoletos         68.7
# 2012-01-01          86               Tres Olivos         58.1
# 2012-01-01          55  Urbanización Embajada II         55.9
# 2012-01-01          50           Pza de Castilla         66.8
# 2012-01-01          48                Castellana         63.9
#
#             sonido_superado_1%  sonido_superado_10%  sonido_superado_50%  \
# mes
# 2012-01-01                74.9                 72.0                 66.5
# 2012-01-01                66.9                 61.2                 52.0
# 2012-01-01                63.5                 58.1                 51.1
# 2012-01-01                72.8                 68.4                 64.9
# 2012-01-01                69.3                 66.5                 62.5
#
#             sonido_superado_90%  sonido_superado_99%
# mes
# 2012-01-01                 59.1                 51.0
# 2012-01-01                 39.3                 36.6
# 2012-01-01                 44.3                 41.3
# 2012-01-01                 58.3                 50.8
# 2012-01-01                 54.8                 46.1

# %%
# Se pivota la tabla para que cada columna sea una zona y los valores sean el valor que supera los que hay el 50% del tiempo 
# Así podemos decir que la mayoría del tiempo se supera tal o cual valor
df_acoustics = df_acoustics.pivot_table(index='mes', columns='zonas', values='sonido_superado_50%')

df_acoustics.head()
# Out:
# zonas       Alto Extremadura  Arturo Soria  Avda de Moratalaz  Barajas Pueblo  \
# mes
# 2012-01-01              57.9          59.7               59.1            54.5
# 2012-02-01              57.6          59.4               58.8            54.6
# 2012-03-01              57.5          59.0               58.3            53.7
# 2012-04-01              57.7          59.0               58.5            53.1
# 2012-05-01              57.2          58.4               58.1            53.5
#
# zonas       Barrio del Pilar  Campo de las Naciones  Carlos V  Casa de Campo  \
# mes
# 2012-01-01              59.9                   57.5       NaN           46.5
# 2012-02-01              59.4                   58.0       NaN           47.5
# 2012-03-01              59.1                   57.4       NaN           48.2
# 2012-04-01              58.7                   56.6       NaN           46.6
# 2012-05-01              59.3                   57.1       NaN           46.8
#
# zonas       Castellana  Cuatro Caminos  ...  Plaza de España  \
# mes                                     ...
# 2012-01-01        62.5            60.9  ...             64.9
# 2012-02-01        62.2            61.6  ...             64.2
# 2012-03-01        62.1            60.8  ...             64.1
# 2012-04-01        62.1            60.3  ...             63.8
# 2012-05-01        61.5            60.6  ...             63.9
#
# zonas       Plaza del Carmen  Pza de Castilla  Ramón y Cajal  Sanchinarro  \
# mes
# 2012-01-01              58.1             64.9           66.5         55.1
# 2012-02-01              57.8             64.6           66.5         54.5
# 2012-03-01              58.5             64.1           66.0         53.2
# 2012-04-01              58.6             64.5           65.7         54.0
# 2012-05-01              59.5             63.9           65.7         53.2
#
# zonas       Santa Eugenia  Tres Olivos  Urbanización Embajada II  Vallecas  \
# mes
# 2012-01-01            NaN         52.0                      51.1      53.8
# 2012-02-01            NaN         51.8                      51.2      54.2
# 2012-03-01            NaN         51.9                      50.3      53.7
# 2012-04-01            NaN         52.6                      50.4      53.4
# 2012-05-01            NaN         52.9                      50.6      54.0
#
# zonas       Villaverde
# mes
# 2012-01-01        52.2
# 2012-02-01        52.2
# 2012-03-01        52.6
# 2012-04-01        52.9
# 2012-05-01        54.3
#
# [5 rows x 31 columns]

# %%
# Plaza de España tiene muchos nulos
df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 132 entries, 2012-01-01 to 2023-02-01
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Alto Extremadura          131 non-null    float64
#  1   Arturo Soria              130 non-null    float64
#  2   Avda de Moratalaz         132 non-null    float64
#  3   Barajas Pueblo            132 non-null    float64
#  4   Barrio del Pilar          132 non-null    float64
#  5   Campo de las Naciones     132 non-null    float64
#  6   Carlos V                  125 non-null    float64
#  7   Casa de Campo             132 non-null    float64
#  8   Castellana                131 non-null    float64
#  9   Cuatro Caminos            131 non-null    float64
#  10  Cuatro Vientos            132 non-null    float64
#  11  El Pardo                  132 non-null    float64
#  12  Embajada                  130 non-null    float64
#  13  Ensanche de Vallecas      126 non-null    float64
#  14  Escuelas Aguirre          126 non-null    float64
#  15  Farolillo                 131 non-null    float64
#  16  Glorieta Fdez. Ladreda    130 non-null    float64
#  17  Gregorio Marañón          125 non-null    float64
#  18  Méndez Álvaro             131 non-null    float64
#  19  Paseo de Recoletos        131 non-null    float64
#  20  Plaza Manuel Becerra      131 non-null    float64
#  21  Plaza de España           104 non-null    float64
#  22  Plaza del Carmen          132 non-null    float64
#  23  Pza de Castilla           131 non-null    float64
#  24  Ramón y Cajal             122 non-null    float64
#  25  Sanchinarro               131 non-null    float64
#  26  Santa Eugenia             125 non-null    float64
#  27  Tres Olivos               132 non-null    float64
#  28  Urbanización Embajada II  132 non-null    float64
#  29  Vallecas                  132 non-null    float64
#  30  Villaverde                131 non-null    float64
# dtypes: float64(31)
# memory usage: 33.0 KB

# %%
# Se establece la frecuencia "MS" ("month start") y se interpolan los nulos
df_acoustics = df_acoustics.asfreq('MS')

df_acoustics = df_acoustics.apply(lambda x: x.interpolate(method='linear'))

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 134 entries, 2012-01-01 to 2023-02-01
# Freq: MS
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Alto Extremadura          134 non-null    float64
#  1   Arturo Soria              134 non-null    float64
#  2   Avda de Moratalaz         134 non-null    float64
#  3   Barajas Pueblo            134 non-null    float64
#  4   Barrio del Pilar          134 non-null    float64
#  5   Campo de las Naciones     134 non-null    float64
#  6   Carlos V                  129 non-null    float64
#  7   Casa de Campo             134 non-null    float64
#  8   Castellana                134 non-null    float64
#  9   Cuatro Caminos            134 non-null    float64
#  10  Cuatro Vientos            134 non-null    float64
#  11  El Pardo                  134 non-null    float64
#  12  Embajada                  134 non-null    float64
#  13  Ensanche de Vallecas      134 non-null    float64
#  14  Escuelas Aguirre          134 non-null    float64
#  15  Farolillo                 134 non-null    float64
#  16  Glorieta Fdez. Ladreda    134 non-null    float64
#  17  Gregorio Marañón          129 non-null    float64
#  18  Méndez Álvaro             134 non-null    float64
#  19  Paseo de Recoletos        134 non-null    float64
#  20  Plaza Manuel Becerra      134 non-null    float64
#  21  Plaza de España           134 non-null    float64
#  22  Plaza del Carmen          134 non-null    float64
#  23  Pza de Castilla           134 non-null    float64
#  24  Ramón y Cajal             134 non-null    float64
#  25  Sanchinarro               134 non-null    float64
#  26  Santa Eugenia             129 non-null    float64
#  27  Tres Olivos               134 non-null    float64
#  28  Urbanización Embajada II  134 non-null    float64
#  29  Vallecas                  134 non-null    float64
#  30  Villaverde                134 non-null    float64
# dtypes: float64(31)
# memory usage: 33.5 KB

# %%
# Hay algunos valores que se resisten a ser imputados por ser los primeros. Se atribuyen al más cercano
df_acoustics.loc[df_acoustics['Carlos V'].isna(), 'Carlos V'] = 67.8
df_acoustics.loc[df_acoustics['Gregorio Marañón'].isna(), 'Gregorio Marañón'] = 66.0
df_acoustics.loc[df_acoustics['Santa Eugenia'].isna(), 'Santa Eugenia'] = 61.8

df_acoustics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 134 entries, 2012-01-01 to 2023-02-01
# Freq: MS
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Alto Extremadura          134 non-null    float64
#  1   Arturo Soria              134 non-null    float64
#  2   Avda de Moratalaz         134 non-null    float64
#  3   Barajas Pueblo            134 non-null    float64
#  4   Barrio del Pilar          134 non-null    float64
#  5   Campo de las Naciones     134 non-null    float64
#  6   Carlos V                  134 non-null    float64
#  7   Casa de Campo             134 non-null    float64
#  8   Castellana                134 non-null    float64
#  9   Cuatro Caminos            134 non-null    float64
#  10  Cuatro Vientos            134 non-null    float64
#  11  El Pardo                  134 non-null    float64
#  12  Embajada                  134 non-null    float64
#  13  Ensanche de Vallecas      134 non-null    float64
#  14  Escuelas Aguirre          134 non-null    float64
#  15  Farolillo                 134 non-null    float64
#  16  Glorieta Fdez. Ladreda    134 non-null    float64
#  17  Gregorio Marañón          134 non-null    float64
#  18  Méndez Álvaro             134 non-null    float64
#  19  Paseo de Recoletos        134 non-null    float64
#  20  Plaza Manuel Becerra      134 non-null    float64
#  21  Plaza de España           134 non-null    float64
#  22  Plaza del Carmen          134 non-null    float64
#  23  Pza de Castilla           134 non-null    float64
#  24  Ramón y Cajal             134 non-null    float64
#  25  Sanchinarro               134 non-null    float64
#  26  Santa Eugenia             134 non-null    float64
#  27  Tres Olivos               134 non-null    float64
#  28  Urbanización Embajada II  134 non-null    float64
#  29  Vallecas                  134 non-null    float64
#  30  Villaverde                134 non-null    float64
# dtypes: float64(31)
# memory usage: 33.5 KB

# %% [markdown]
# ### Guardado df_acoustics

# %%
df_acoustics.to_csv('data/processed/acoustics.csv')

df_acoustics.head()
# Out:
# zonas       Alto Extremadura  Arturo Soria  Avda de Moratalaz  Barajas Pueblo  \
# mes
# 2012-01-01              57.9          59.7               59.1            54.5
# 2012-02-01              57.6          59.4               58.8            54.6
# 2012-03-01              57.5          59.0               58.3            53.7
# 2012-04-01              57.7          59.0               58.5            53.1
# 2012-05-01              57.2          58.4               58.1            53.5
#
# zonas       Barrio del Pilar  Campo de las Naciones  Carlos V  Casa de Campo  \
# mes
# 2012-01-01              59.9                   57.5      67.8           46.5
# 2012-02-01              59.4                   58.0      67.8           47.5
# 2012-03-01              59.1                   57.4      67.8           48.2
# 2012-04-01              58.7                   56.6      67.8           46.6
# 2012-05-01              59.3                   57.1      67.8           46.8
#
# zonas       Castellana  Cuatro Caminos  ...  Plaza de España  \
# mes                                     ...
# 2012-01-01        62.5            60.9  ...             64.9
# 2012-02-01        62.2            61.6  ...             64.2
# 2012-03-01        62.1            60.8  ...             64.1
# 2012-04-01        62.1            60.3  ...             63.8
# 2012-05-01        61.5            60.6  ...             63.9
#
# zonas       Plaza del Carmen  Pza de Castilla  Ramón y Cajal  Sanchinarro  \
# mes
# 2012-01-01              58.1             64.9           66.5         55.1
# 2012-02-01              57.8             64.6           66.5         54.5
# 2012-03-01              58.5             64.1           66.0         53.2
# 2012-04-01              58.6             64.5           65.7         54.0
# 2012-05-01              59.5             63.9           65.7         53.2
#
# zonas       Santa Eugenia  Tres Olivos  Urbanización Embajada II  Vallecas  \
# mes
# 2012-01-01           61.8         52.0                      51.1      53.8
# 2012-02-01           61.8         51.8                      51.2      54.2
# 2012-03-01           61.8         51.9                      50.3      53.7
# 2012-04-01           61.8         52.6                      50.4      53.4
# 2012-05-01           61.8         52.9                      50.6      54.0
#
# zonas       Villaverde
# mes
# 2012-01-01        52.2
# 2012-02-01        52.2
# 2012-03-01        52.6
# 2012-04-01        52.9
# 2012-05-01        54.3
#
# [5 rows x 31 columns]

# %%
df_acoustics = pd.read_csv('data/processed/acoustics.csv', parse_dates=['mes'], index_col='mes')
df_acoustics = df_acoustics.asfreq('MS')

df_acoustics.head()
# Out:
#             Alto Extremadura  Arturo Soria  Avda de Moratalaz  Barajas Pueblo  \
# mes
# 2012-01-01              57.9          59.7               59.1            54.5
# 2012-02-01              57.6          59.4               58.8            54.6
# 2012-03-01              57.5          59.0               58.3            53.7
# 2012-04-01              57.7          59.0               58.5            53.1
# 2012-05-01              57.2          58.4               58.1            53.5
#
#             Barrio del Pilar  Campo de las Naciones  Carlos V  Casa de Campo  \
# mes
# 2012-01-01              59.9                   57.5      67.8           46.5
# 2012-02-01              59.4                   58.0      67.8           47.5
# 2012-03-01              59.1                   57.4      67.8           48.2
# 2012-04-01              58.7                   56.6      67.8           46.6
# 2012-05-01              59.3                   57.1      67.8           46.8
#
#             Castellana  Cuatro Caminos  ...  Plaza de España  \
# mes                                     ...
# 2012-01-01        62.5            60.9  ...             64.9
# 2012-02-01        62.2            61.6  ...             64.2
# 2012-03-01        62.1            60.8  ...             64.1
# 2012-04-01        62.1            60.3  ...             63.8
# 2012-05-01        61.5            60.6  ...             63.9
#
#             Plaza del Carmen  Pza de Castilla  Ramón y Cajal  Sanchinarro  \
# mes
# 2012-01-01              58.1             64.9           66.5         55.1
# 2012-02-01              57.8             64.6           66.5         54.5
# 2012-03-01              58.5             64.1           66.0         53.2
# 2012-04-01              58.6             64.5           65.7         54.0
# 2012-05-01              59.5             63.9           65.7         53.2
#
#             Santa Eugenia  Tres Olivos  Urbanización Embajada II  Vallecas  \
# mes
# 2012-01-01           61.8         52.0                      51.1      53.8
# 2012-02-01           61.8         51.8                      51.2      54.2
# 2012-03-01           61.8         51.9                      50.3      53.7
# 2012-04-01           61.8         52.6                      50.4      53.4
# 2012-05-01           61.8         52.9                      50.6      54.0
#
#             Villaverde
# mes
# 2012-01-01        52.2
# 2012-02-01        52.2
# 2012-03-01        52.6
# 2012-04-01        52.9
# 2012-05-01        54.3
#
# [5 rows x 31 columns]

# %% [markdown]
# # Análisis de estacionalidad y estacionaridad

# %%
# Todas las zonas. Se percibe que la estacionalidad puede ser aditiva
df_acoustics.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Solo el primero
df_acoustics['Alto Extremadura'].plot()
plt.show()

# %%
# Descomposición estacional del primero. La estacionalidad es clara
sm.tsa.seasonal_decompose(df_acoustics['Alto Extremadura'], model="additive", period=12).plot()
plt.show()

# %%
# Las zonas no son estacionarias
p_values = dict()
for zona in df_acoustics.columns:
    dickey_fuller = sts.adfuller(df_acoustics[zona])
    p_value = dickey_fuller[1]
    p_values[zona] = p_value
    if p_value > 0.05:
        print(f'La zona de {zona} no es estacionaria (p valor = {p_value})')
# Out:
# La zona de Alto Extremadura no es estacionaria (p valor = 0.9154044813456497)
# La zona de Arturo Soria no es estacionaria (p valor = 0.7958608838409755)
# La zona de Avda de Moratalaz no es estacionaria (p valor = 0.8130201768006494)
# La zona de Barrio del Pilar no es estacionaria (p valor = 0.615021709323205)
# La zona de Campo de las Naciones no es estacionaria (p valor = 0.27036291208420343)
# La zona de Carlos V no es estacionaria (p valor = 0.868869406562577)
# La zona de Casa de Campo no es estacionaria (p valor = 0.14112227739647426)
# La zona de Castellana no es estacionaria (p valor = 0.825989710224537)
# La zona de Cuatro Caminos no es estacionaria (p valor = 0.6235118156073408)
# La zona de Cuatro Vientos no es estacionaria (p valor = 0.3399343525609905)
# La zona de Ensanche de Vallecas no es estacionaria (p valor = 0.29404199505177514)
# La zona de Escuelas Aguirre no es estacionaria (p valor = 0.8890834198089461)
# La zona de Farolillo no es estacionaria (p valor = 0.7305041890635429)
# La zona de Glorieta Fdez. Ladreda no es estacionaria (p valor = 0.9354140619950387)
# La zona de Méndez Álvaro no es estacionaria (p valor = 0.41925347384171563)
# La zona de Paseo de Recoletos no es estacionaria (p valor = 0.8647344643971748)
# La zona de Plaza Manuel Becerra no es estacionaria (p valor = 0.6980097975638363)
# La zona de Plaza de España no es estacionaria (p valor = 0.7170945136349212)
# La zona de Plaza del Carmen no es estacionaria (p valor = 0.2869060542563806)
# La zona de Ramón y Cajal no es estacionaria (p valor = 0.5416852130026325)
# La zona de Sanchinarro no es estacionaria (p valor = 0.5806374598555654)
# La zona de Santa Eugenia no es estacionaria (p valor = 0.22032056023270846)
# La zona de Tres Olivos no es estacionaria (p valor = 0.9076377030120908)
# La zona de Vallecas no es estacionaria (p valor = 0.3300494655562733)
# La zona de Villaverde no es estacionaria (p valor = 0.6173037869654265)

# %% [markdown]
# # Preprocesado (Holt-Winters)

# %% [markdown]
# ### Ejemplo con la primera zona

# %%
# Se incrementa al máximo el "train" para compensar la gran bajada de la pandemia
size = int(len(df_acoustics)*0.9)
df_train_example = df_acoustics.iloc[:size].copy()
df_test_example = df_acoustics.iloc[size:].copy()

# %%
# Tendencia
ciclo, tendencia = sm.tsa.filters.hpfilter(df_train_example['Alto Extremadura'])
df_train_example['Alto Extremadura_tendencia'] = tendencia

# %%
# Medias móviles
df_train_example['Alto Extremadura_MM'] = df_train_example['Alto Extremadura'].rolling(5).mean()

# %%
# Medias móviles ponderadas, dan más importancia a los datos recientes
df_train_example['Alto Extremadura_MMP'] = df_train_example['Alto Extremadura'].ewm(alpha=0.2).mean()

# %%
# Suavizado simple
df_train_example['Alto Extremadura_EXPS'] = SimpleExpSmoothing(df_train_example['Alto Extremadura']).fit(smoothing_level=0.2).fittedvalues.shift(-1)

# %%
# Suavizado doble
df_train_example['Alto Extremadura_EXPS2'] = ExponentialSmoothing(df_train_example['Alto Extremadura']).fit(smoothing_level=0.2).fittedvalues.shift(-1)

# %%
# Suavizado triple
df_train_example['Alto Extremadura_EXPS3'] = ExponentialSmoothing(df_train_example['Alto Extremadura'], trend="add", seasonal="add", seasonal_periods=12).fit(smoothing_level=0.2).fittedvalues

# %%
# Las medias móviles ponderadas, EXPS y EXPS2 coinciden
df_train_example[['Alto Extremadura', 
                    'Alto Extremadura_tendencia',
                    'Alto Extremadura_MM',
                    'Alto Extremadura_MMP',
                    'Alto Extremadura_EXPS',
                    'Alto Extremadura_EXPS2',
                    'Alto Extremadura_EXPS3'
                    ]
                ].plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
test = df_test_example['Alto Extremadura']

test
# Out:
# mes
# 2022-01-01    55.2
# 2022-02-01    55.1
# 2022-03-01    55.8
# 2022-04-01    53.2
# 2022-05-01    55.0
# 2022-06-01    55.0
# 2022-07-01    53.4
# 2022-08-01    51.9
# 2022-09-01    54.0
# 2022-10-01    54.0
# 2022-11-01    55.2
# 2022-12-01    55.3
# 2023-01-01    55.0
# 2023-02-01    54.4
# Freq: MS, Name: Alto Extremadura, dtype: float64

# %%
# Predicción como ejemplo con suavizado triple
model = ExponentialSmoothing(df_train_example['Alto Extremadura'], trend="add", seasonal="add", seasonal_periods=12).fit()

test = df_test_example['Alto Extremadura']
pred = model.forecast(len(test))

pred
# Out:
# 2022-01-01    55.317592
# 2022-02-01    55.667590
# 2022-03-01    54.937590
# 2022-04-01    54.367594
# 2022-05-01    54.187596
# 2022-06-01    54.144262
# 2022-07-01    54.110930
# 2022-08-01    52.697596
# 2022-09-01    54.227597
# 2022-10-01    54.577595
# 2022-11-01    55.147595
# 2022-12-01    55.267595
# 2023-01-01    55.064844
# 2023-02-01    55.414842
# Freq: MS, dtype: float64

# %%
# Métricas de prueba
print(f'rmse: {mean_squared_error(test, pred, squared=False)}')
print(f'mse: {mean_squared_error(test, pred)}')
print(f'mae: {mean_absolute_error(test,pred)}')
print(f'r2: {r2_score(test, pred)}')
print(f'mape: {mean_absolute_percentage_error(test, pred)}')
# Out:
# rmse: 0.6761342225601906
# mse: 0.45715748691707336
# mae: 0.5615387806156669
# r2: 0.560791787482249
# mape: 0.010366114069049456

# %% [markdown]
# ### Con todas las zonas

# %%
size = int(len(df_acoustics)*0.9)
df_train = df_acoustics.iloc[:size].copy()
df_test = df_acoustics.iloc[size:].copy()

# %%
# Hay que buscar un modelo que capture mejor la complejidad
r2_dict = dict()
for col in df_train.columns:
    test = df_test[col]
    r2_list = []
    for alpha in np.arange(0.01, 1.01, 0.01).tolist():
        model_simple = SimpleExpSmoothing(df_train[col]).fit(smoothing_level=alpha)
        model_double = ExponentialSmoothing(df_train[col]).fit(smoothing_level=alpha)
        model_triple = ExponentialSmoothing(df_train[col], trend='add', seasonal='add', seasonal_periods=12).fit(smoothing_level=alpha)
        for model, model_name in [[model_simple, 'model_simple'], [model_double, 'model_double'], [model_triple, 'model_triple']]:
            pred = model.forecast(len(test))
            r2 = r2_score(test, pred)
            r2_list.append([r2, model_name, alpha])
    best = sorted(r2_list, reverse=True)[0]
    r2_dict[col] = best

r2_dict
# Out:
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# {'Alto Extremadura': [0.5973056066413809, 'model_triple', 0.18000000000000002],
#  'Arturo Soria': [-4.07698663713596e-05, 'model_simple', 0.26],
#  'Avda de Moratalaz': [0.5147805921949751, 'model_triple', 0.01],
#  'Barajas Pueblo': [-0.2632199248904097, 'model_simple', 0.62],
#  'Barrio del Pilar': [-4.172367924271114e-06,
#   'model_simple',
#   0.7000000000000001],
#  'Campo de las Naciones': [-8.106974235633224e-05,
#   'model_simple',
#   0.18000000000000002],
#  'Carlos V': [-0.04060435468916279, 'model_double', 0.09],
#  'Casa de Campo': [-0.006475077683593344, 'model_double', 0.02],
#  'Castellana': [0.7978096153047222, 'model_triple', 0.21000000000000002],
#  'Cuatro Caminos': [0.5119056234724884, 'model_triple', 0.27],
#  'Cuatro Vientos': [-0.38312279446481545, 'model_double', 0.04],
#  'El Pardo': [0.18811975465621433, 'model_triple', 0.28],
#  'Embajada': [0.26709227096697274, 'model_triple', 1.0],
#  'Ensanche de Vallecas': [0.3991160838330674, 'model_triple', 0.01],
#  'Escuelas Aguirre': [0.26620784488755755, 'model_triple', 0.01],
#  'Farolillo': [0.641577405155166, 'model_triple', 0.31],
#  'Glorieta Fdez. Ladreda': [-0.3922989716058287,
#   'model_triple',
#   0.5700000000000001],
#  'Gregorio Marañón': [0.719483988204766, 'model_triple', 0.03],
#  'Méndez Álvaro': [0.595684662242681, 'model_triple', 0.11],
#  'Paseo de Recoletos': [0.3385462585220277, 'model_triple', 0.22],
#  'Plaza Manuel Becerra': [0.24556608312033057, 'model_triple', 1.0],
#  'Plaza de España': [-2.0152131530171147e-06, 'model_simple', 0.22],
#  'Plaza del Carmen': [-0.02307002600178998, 'model_double', 0.01],
#  'Pza de Castilla': [0.4086544413090565, 'model_triple', 0.29000000000000004],
#  'Ramón y Cajal': [0.4222212329368016, 'model_triple', 0.01],
#  'Sanchinarro': [0.644279339548167, 'model_triple', 0.22],
#  'Santa Eugenia': [0.2880245719909059, 'model_triple', 0.24000000000000002],
#  'Tres Olivos': [0.5009406183025154, 'model_triple', 0.06999999999999999],
#  'Urbanización Embajada II': [0.06164820686430228, 'model_triple', 0.3],
#  'Vallecas': [-7.72678321259157e-06, 'model_simple', 0.48000000000000004],
#  'Villaverde': [0.5126856623495261, 'model_triple', 0.01]}

# %%
# Se crea un dataframe nuevo de entrenamiento con los datos suavizados para cada zona con el mejor método respectivo
df_train_smoothed = pd.DataFrame({'A' : []})

for key, value in r2_dict.items():
    if value[1] == 'model_simple':
        df_train_smoothed[key] = SimpleExpSmoothing(df_train[key]).fit(smoothing_level=value[2]).fittedvalues
    elif value[1] == 'model_double':
        df_train_smoothed[key] = ExponentialSmoothing(df_train[key]).fit(smoothing_level=value[2]).fittedvalues.shift(-1)
    else:
        df_train_smoothed[key] = ExponentialSmoothing(df_train[key], trend='add', seasonal='add', seasonal_periods=12).fit(smoothing_level=value[2]).fittedvalues

df_train_smoothed = df_train_smoothed.drop(columns='A')
# Out:
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\holtwinters\_smoothers.py:138: RuntimeWarning: divide by zero encountered in double_scalars
#   g = (g - lb) / (ub - lb)

# %%
# El dataframe suavizado tiene algunos nulos
df_train_smoothed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2012-01-01 to 2021-12-01
# Freq: MS
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Alto Extremadura          120 non-null    float64
#  1   Arturo Soria              120 non-null    float64
#  2   Avda de Moratalaz         120 non-null    float64
#  3   Barajas Pueblo            120 non-null    float64
#  4   Barrio del Pilar          120 non-null    float64
#  5   Campo de las Naciones     120 non-null    float64
#  6   Carlos V                  119 non-null    float64
#  7   Casa de Campo             119 non-null    float64
#  8   Castellana                120 non-null    float64
#  9   Cuatro Caminos            120 non-null    float64
#  10  Cuatro Vientos            119 non-null    float64
#  11  El Pardo                  120 non-null    float64
#  12  Embajada                  120 non-null    float64
#  13  Ensanche de Vallecas      120 non-null    float64
#  14  Escuelas Aguirre          120 non-null    float64
#  15  Farolillo                 120 non-null    float64
#  16  Glorieta Fdez. Ladreda    120 non-null    float64
#  17  Gregorio Marañón          120 non-null    float64
#  18  Méndez Álvaro             120 non-null    float64
#  19  Paseo de Recoletos        120 non-null    float64
#  20  Plaza Manuel Becerra      120 non-null    float64
#  21  Plaza de España           120 non-null    float64
#  22  Plaza del Carmen          119 non-null    float64
#  23  Pza de Castilla           120 non-null    float64
#  24  Ramón y Cajal             120 non-null    float64
#  25  Sanchinarro               120 non-null    float64
#  26  Santa Eugenia             120 non-null    float64
#  27  Tres Olivos               120 non-null    float64
#  28  Urbanización Embajada II  120 non-null    float64
#  29  Vallecas                  120 non-null    float64
#  30  Villaverde                120 non-null    float64
# dtypes: float64(31)
# memory usage: 30.0 KB

# %%
# Se interpolan como antes
df_train_smoothed = df_train_smoothed.apply(lambda x: x.interpolate(method='linear'))

df_train_smoothed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2012-01-01 to 2021-12-01
# Freq: MS
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Alto Extremadura          120 non-null    float64
#  1   Arturo Soria              120 non-null    float64
#  2   Avda de Moratalaz         120 non-null    float64
#  3   Barajas Pueblo            120 non-null    float64
#  4   Barrio del Pilar          120 non-null    float64
#  5   Campo de las Naciones     120 non-null    float64
#  6   Carlos V                  120 non-null    float64
#  7   Casa de Campo             120 non-null    float64
#  8   Castellana                120 non-null    float64
#  9   Cuatro Caminos            120 non-null    float64
#  10  Cuatro Vientos            120 non-null    float64
#  11  El Pardo                  120 non-null    float64
#  12  Embajada                  120 non-null    float64
#  13  Ensanche de Vallecas      120 non-null    float64
#  14  Escuelas Aguirre          120 non-null    float64
#  15  Farolillo                 120 non-null    float64
#  16  Glorieta Fdez. Ladreda    120 non-null    float64
#  17  Gregorio Marañón          120 non-null    float64
#  18  Méndez Álvaro             120 non-null    float64
#  19  Paseo de Recoletos        120 non-null    float64
#  20  Plaza Manuel Becerra      120 non-null    float64
#  21  Plaza de España           120 non-null    float64
#  22  Plaza del Carmen          120 non-null    float64
#  23  Pza de Castilla           120 non-null    float64
#  24  Ramón y Cajal             120 non-null    float64
#  25  Sanchinarro               120 non-null    float64
#  26  Santa Eugenia             120 non-null    float64
#  27  Tres Olivos               120 non-null    float64
#  28  Urbanización Embajada II  120 non-null    float64
#  29  Vallecas                  120 non-null    float64
#  30  Villaverde                120 non-null    float64
# dtypes: float64(31)
# memory usage: 30.0 KB

# %% [markdown]
# ### Guardado df_train_smoothed y df_test

# %%
df_train_smoothed.to_csv('data/processed/train_smoothed.csv')
df_test.to_csv('data/processed/test.csv')

df_train_smoothed.head()
# Out:
#             Alto Extremadura  Arturo Soria  Avda de Moratalaz  Barajas Pueblo  \
# mes
# 2012-01-01         57.939021     59.021996          59.028664       54.381133
# 2012-02-01         58.281890     59.198277          59.229380       54.454830
# 2012-03-01         57.429226     59.250725          58.595083       54.544836
# 2012-04-01         56.871939     59.185536          58.462129       54.021038
# 2012-05-01         56.841001     59.137297          58.222510       53.449994
#
#             Barrio del Pilar  Campo de las Naciones   Carlos V  Casa de Campo  \
# mes
# 2012-01-01         59.717637              56.960203  67.726929      45.691638
# 2012-02-01         59.845291              57.057366  67.733506      45.727805
# 2012-03-01         59.533587              57.227040  67.739490      45.777249
# 2012-04-01         59.230076              57.258173  67.744936      45.793704
# 2012-05-01         58.859023              57.139702  67.749892      45.813830
#
#             Castellana  Cuatro Caminos  ...  Plaza de España  \
# mes                                     ...
# 2012-01-01   62.604461       61.340828  ...        64.178890
# 2012-02-01   62.962623       61.681868  ...        64.337534
# 2012-03-01   61.982407       60.499826  ...        64.307277
# 2012-04-01   61.207140       59.790790  ...        64.261676
# 2012-05-01   60.954614       59.948346  ...        64.160107
#
#             Plaza del Carmen  Pza de Castilla  Ramón y Cajal  Sanchinarro  \
# mes
# 2012-01-01         57.966753        65.103836      67.235904    55.525352
# 2012-02-01         57.965086        65.184726      67.698522    55.261778
# 2012-03-01         57.970435        64.235051      66.536567    53.564193
# 2012-04-01         57.976730        63.525998      65.811177    52.704066
# 2012-05-01         57.991963        63.677852      65.910019    52.769165
#
#             Santa Eugenia  Tres Olivos  Urbanización Embajada II   Vallecas  \
# mes
# 2012-01-01      61.636244    52.471748                 50.996554  53.891094
# 2012-02-01      61.865778    52.978725                 51.267581  53.847369
# 2012-03-01      61.249783    52.256217                 50.837322  54.016632
# 2012-04-01      60.891739    52.351279                 50.126138  53.864649
# 2012-05-01      60.879667    52.378690                 50.338293  53.641617
#
#             Villaverde
# mes
# 2012-01-01   52.936588
# 2012-02-01   53.229279
# 2012-03-01   52.938876
# 2012-04-01   53.085600
# 2012-05-01   54.193881
#
# [5 rows x 31 columns]

# %%
df_train_smoothed = pd.read_csv('data/processed/train_smoothed.csv', parse_dates=['mes'], index_col='mes')
df_test = pd.read_csv('data/processed/test.csv', parse_dates=['mes'], index_col='mes')

df_train_smoothed = df_train_smoothed.asfreq('MS')
df_test = df_test.asfreq('MS')

df_train_smoothed.head()
# Out:
#             Alto Extremadura  Arturo Soria  Avda de Moratalaz  Barajas Pueblo  \
# mes
# 2012-01-01         57.939021     59.021996          59.028664       54.381133
# 2012-02-01         58.281890     59.198277          59.229380       54.454830
# 2012-03-01         57.429226     59.250725          58.595083       54.544836
# 2012-04-01         56.871939     59.185536          58.462129       54.021038
# 2012-05-01         56.841001     59.137297          58.222510       53.449994
#
#             Barrio del Pilar  Campo de las Naciones   Carlos V  Casa de Campo  \
# mes
# 2012-01-01         59.717637              56.960203  67.726929      45.691638
# 2012-02-01         59.845291              57.057366  67.733506      45.727805
# 2012-03-01         59.533587              57.227040  67.739490      45.777249
# 2012-04-01         59.230076              57.258173  67.744936      45.793704
# 2012-05-01         58.859023              57.139702  67.749892      45.813830
#
#             Castellana  Cuatro Caminos  ...  Plaza de España  \
# mes                                     ...
# 2012-01-01   62.604461       61.340828  ...        64.178890
# 2012-02-01   62.962623       61.681868  ...        64.337534
# 2012-03-01   61.982407       60.499826  ...        64.307277
# 2012-04-01   61.207140       59.790790  ...        64.261676
# 2012-05-01   60.954614       59.948346  ...        64.160107
#
#             Plaza del Carmen  Pza de Castilla  Ramón y Cajal  Sanchinarro  \
# mes
# 2012-01-01         57.966753        65.103836      67.235904    55.525352
# 2012-02-01         57.965086        65.184726      67.698522    55.261778
# 2012-03-01         57.970435        64.235051      66.536567    53.564193
# 2012-04-01         57.976730        63.525998      65.811177    52.704066
# 2012-05-01         57.991963        63.677852      65.910019    52.769165
#
#             Santa Eugenia  Tres Olivos  Urbanización Embajada II   Vallecas  \
# mes
# 2012-01-01      61.636244    52.471748                 50.996554  53.891094
# 2012-02-01      61.865778    52.978725                 51.267581  53.847369
# 2012-03-01      61.249783    52.256217                 50.837322  54.016632
# 2012-04-01      60.891739    52.351279                 50.126138  53.864649
# 2012-05-01      60.879667    52.378690                 50.338293  53.641617
#
#             Villaverde
# mes
# 2012-01-01   52.936588
# 2012-02-01   53.229279
# 2012-03-01   52.938876
# 2012-04-01   53.085600
# 2012-05-01   54.193881
#
# [5 rows x 31 columns]

# %% [markdown]
# # Modelaje

# %% [markdown]
# ## ARIMA

# %% [markdown]
# ### Entrenamiento

# %%
# Se guardan los mejores hiperparámetros, el modelo, la r2 y el mae de cada zona en un diccionario
zone_dict = dict()
for col in df_train_smoothed.columns:
    model = auto_arima(df_train_smoothed[col], seasonal=True, m=12, trace=True, error_action='ignore', suppress_warnings=True)
    best_order = model.order
    best_seasonal_order = model.seasonal_order
    pred = model.predict(start=len(df_train_smoothed), n_periods=len(df_test))
    test = df_test[col]
    r2 = r2_score(test, pred)
    mae = mean_absolute_error(test, pred)
    zone_dict[col] = {'params': best_order + best_seasonal_order,
                      'model': model,
                      'r2': r2,
                      'mae': mae
                      }
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=-97.146, Time=1.61 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-17.183, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-77.335, Time=0.27 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=-85.680, Time=0.44 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=-98.805, Time=1.11 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=-65.731, Time=0.40 sec
#  ARIMA(2,1,2)(0,1,2)[12]             : AIC=-97.245, Time=3.28 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=-89.377, Time=0.87 sec
#  ARIMA(2,1,2)(1,1,2)[12]             : AIC=inf, Time=3.63 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=-99.114, Time=0.96 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=-60.753, Time=0.19 sec
#  ARIMA(1,1,2)(1,1,1)[12]             : AIC=-97.308, Time=1.42 sec
#  ARIMA(1,1,2)(0,1,2)[12]             : AIC=-97.485, Time=1.83 sec
#  ARIMA(1,1,2)(1,1,0)[12]             : AIC=-84.413, Time=0.58 sec
#  ARIMA(1,1,2)(1,1,2)[12]             : AIC=inf, Time=3.38 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=-100.167, Time=0.63 sec
#  ARIMA(0,1,2)(0,1,0)[12]             : AIC=-62.105, Time=0.21 sec
#  ARIMA(0,1,2)(1,1,1)[12]             : AIC=-98.486, Time=1.04 sec
#  ARIMA(0,1,2)(0,1,2)[12]             : AIC=-98.752, Time=1.35 sec
#  ARIMA(0,1,2)(1,1,0)[12]             : AIC=-86.209, Time=0.44 sec
#  ARIMA(0,1,2)(1,1,2)[12]             : AIC=inf, Time=2.75 sec
#  ARIMA(0,1,3)(0,1,1)[12]             : AIC=-100.191, Time=1.05 sec
#  ARIMA(0,1,3)(0,1,0)[12]             : AIC=inf, Time=0.76 sec
#  ARIMA(0,1,3)(1,1,1)[12]             : AIC=-98.250, Time=1.53 sec
#  ARIMA(0,1,3)(0,1,2)[12]             : AIC=-98.310, Time=1.94 sec
#  ARIMA(0,1,3)(1,1,0)[12]             : AIC=-84.750, Time=0.68 sec
#  ARIMA(0,1,3)(1,1,2)[12]             : AIC=inf, Time=3.53 sec
#  ARIMA(1,1,3)(0,1,1)[12]             : AIC=-100.846, Time=1.77 sec
#  ARIMA(1,1,3)(0,1,0)[12]             : AIC=-66.500, Time=0.38 sec
#  ARIMA(1,1,3)(1,1,1)[12]             : AIC=-98.866, Time=2.03 sec
#  ARIMA(1,1,3)(0,1,2)[12]             : AIC=-98.883, Time=2.25 sec
#  ARIMA(1,1,3)(1,1,0)[12]             : AIC=-86.646, Time=0.87 sec
#  ARIMA(1,1,3)(1,1,2)[12]             : AIC=inf, Time=3.95 sec
#  ARIMA(2,1,3)(0,1,1)[12]             : AIC=-100.548, Time=1.72 sec
#  ARIMA(1,1,4)(0,1,1)[12]             : AIC=-99.115, Time=1.97 sec
#  ARIMA(0,1,4)(0,1,1)[12]             : AIC=-99.248, Time=1.35 sec
#  ARIMA(2,1,4)(0,1,1)[12]             : AIC=-102.536, Time=2.47 sec
#  ARIMA(2,1,4)(0,1,0)[12]             : AIC=-75.756, Time=0.93 sec
#  ARIMA(2,1,4)(1,1,1)[12]             : AIC=-96.743, Time=2.27 sec
#  ARIMA(2,1,4)(0,1,2)[12]             : AIC=-100.851, Time=4.31 sec
#  ARIMA(2,1,4)(1,1,0)[12]             : AIC=-92.683, Time=1.76 sec
#  ARIMA(2,1,4)(1,1,2)[12]             : AIC=inf, Time=4.89 sec
#  ARIMA(3,1,4)(0,1,1)[12]             : AIC=-101.423, Time=2.35 sec
#  ARIMA(2,1,5)(0,1,1)[12]             : AIC=inf, Time=3.13 sec
#  ARIMA(1,1,5)(0,1,1)[12]             : AIC=-98.163, Time=2.10 sec
#  ARIMA(3,1,3)(0,1,1)[12]             : AIC=-99.384, Time=2.02 sec
#  ARIMA(3,1,5)(0,1,1)[12]             : AIC=-101.312, Time=3.03 sec
#  ARIMA(2,1,4)(0,1,1)[12] intercept   : AIC=-95.132, Time=1.81 sec
#
# Best model:  ARIMA(2,1,4)(0,1,1)[12]
# Total fit time: 83.351 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=69.891, Time=1.21 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=144.739, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=84.301, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=93.616, Time=0.29 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=143.813, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=84.613, Time=0.61 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=78.682, Time=0.57 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=71.245, Time=2.47 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=70.923, Time=2.43 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=97.934, Time=0.27 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=82.785, Time=1.48 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=74.129, Time=1.45 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=73.891, Time=2.49 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=58.661, Time=1.06 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=66.813, Time=0.80 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=63.398, Time=0.83 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=58.944, Time=2.57 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=57.878, Time=1.97 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=65.366, Time=1.39 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=60.804, Time=2.59 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=71.996, Time=1.51 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=69.425, Time=1.60 sec
#  ARIMA(3,1,1)(1,0,2)[12] intercept   : AIC=68.505, Time=2.06 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=73.227, Time=1.06 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=79.873, Time=1.92 sec
#  ARIMA(3,1,0)(1,0,2)[12] intercept   : AIC=66.165, Time=1.54 sec
#  ARIMA(3,1,2)(1,0,2)[12] intercept   : AIC=60.857, Time=2.76 sec
#  ARIMA(2,1,1)(1,0,2)[12]             : AIC=56.845, Time=1.51 sec
#  ARIMA(2,1,1)(0,0,2)[12]             : AIC=65.912, Time=0.73 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=55.782, Time=0.61 sec
#  ARIMA(2,1,1)(0,0,1)[12]             : AIC=67.883, Time=0.29 sec
#  ARIMA(2,1,1)(1,0,0)[12]             : AIC=63.928, Time=0.58 sec
#  ARIMA(2,1,1)(2,0,1)[12]             : AIC=57.051, Time=1.19 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=76.467, Time=0.12 sec
#  ARIMA(2,1,1)(2,0,0)[12]             : AIC=59.701, Time=0.62 sec
#  ARIMA(2,1,1)(2,0,2)[12]             : AIC=59.699, Time=2.23 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=70.056, Time=0.37 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=67.141, Time=0.39 sec
#  ARIMA(3,1,1)(1,0,1)[12]             : AIC=57.711, Time=1.04 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=68.061, Time=1.02 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=71.723, Time=0.36 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=76.516, Time=0.74 sec
#  ARIMA(3,1,0)(1,0,1)[12]             : AIC=63.892, Time=0.41 sec
#  ARIMA(3,1,2)(1,0,1)[12]             : AIC=58.710, Time=0.91 sec
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12]
# Total fit time: 51.556 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=-734.782, Time=2.18 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-658.814, Time=0.09 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-728.660, Time=0.23 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=-722.148, Time=0.66 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=-739.428, Time=0.52 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=-724.838, Time=0.17 sec
#  ARIMA(2,1,2)(0,1,2)[12]             : AIC=-744.010, Time=7.20 sec
#  ARIMA(2,1,2)(1,1,2)[12]             : AIC=-741.062, Time=5.36 sec
#  ARIMA(1,1,2)(0,1,2)[12]             : AIC=inf, Time=3.21 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=-738.003, Time=5.10 sec
#  ARIMA(3,1,2)(0,1,2)[12]             : AIC=-727.231, Time=5.22 sec
#  ARIMA(2,1,3)(0,1,2)[12]             : AIC=-746.535, Time=4.78 sec
#  ARIMA(2,1,3)(0,1,1)[12]             : AIC=-743.269, Time=2.99 sec
#  ARIMA(2,1,3)(1,1,2)[12]             : AIC=-744.312, Time=4.84 sec
#  ARIMA(2,1,3)(1,1,1)[12]             : AIC=-743.744, Time=3.77 sec
#  ARIMA(1,1,3)(0,1,2)[12]             : AIC=-731.808, Time=2.74 sec
#  ARIMA(3,1,3)(0,1,2)[12]             : AIC=-743.188, Time=5.22 sec
#  ARIMA(2,1,4)(0,1,2)[12]             : AIC=-735.843, Time=4.70 sec
#  ARIMA(1,1,4)(0,1,2)[12]             : AIC=-746.704, Time=8.17 sec
#  ARIMA(1,1,4)(0,1,1)[12]             : AIC=-745.356, Time=2.97 sec
#  ARIMA(1,1,4)(1,1,2)[12]             : AIC=-742.723, Time=4.61 sec
#  ARIMA(1,1,4)(1,1,1)[12]             : AIC=-737.100, Time=2.32 sec
#  ARIMA(0,1,4)(0,1,2)[12]             : AIC=inf, Time=5.20 sec
#  ARIMA(1,1,5)(0,1,2)[12]             : AIC=-743.056, Time=8.37 sec
#  ARIMA(0,1,3)(0,1,2)[12]             : AIC=-747.464, Time=6.81 sec
#  ARIMA(0,1,3)(0,1,1)[12]             : AIC=-747.743, Time=2.86 sec
#  ARIMA(0,1,3)(0,1,0)[12]             : AIC=-730.455, Time=0.68 sec
#  ARIMA(0,1,3)(1,1,1)[12]             : AIC=-740.903, Time=2.74 sec
#  ARIMA(0,1,3)(1,1,0)[12]             : AIC=-738.136, Time=0.78 sec
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\pmdarima\arima\_auto_solvers.py:40: RuntimeWarning: invalid value encountered in divide
#   max_invroot = max(0, *np.abs(1 / model.maroots()))
#  ARIMA(0,1,3)(1,1,2)[12]             : AIC=-721.918, Time=0.78 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=-739.966, Time=1.16 sec
#  ARIMA(1,1,3)(0,1,1)[12]             : AIC=-745.717, Time=2.16 sec
#  ARIMA(0,1,4)(0,1,1)[12]             : AIC=-746.908, Time=3.03 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=-739.744, Time=1.88 sec
#  ARIMA(0,1,3)(0,1,1)[12] intercept   : AIC=-745.689, Time=3.29 sec
#
# Best model:  ARIMA(0,1,3)(0,1,1)[12]
# Total fit time: 116.876 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.18 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=301.091, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=298.894, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=297.128, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=299.109, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=295.747, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=296.988, Time=0.13 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=294.372, Time=0.10 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=294.846, Time=0.26 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=295.115, Time=0.26 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=297.872, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=296.371, Time=0.15 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=294.925, Time=0.13 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=296.735, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=292.381, Time=0.08 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=292.851, Time=0.25 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=293.121, Time=0.21 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=inf, Time=1.10 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=293.753, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=295.879, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=294.380, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=288.323, Time=0.15 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=289.490, Time=0.32 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=289.638, Time=0.38 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=inf, Time=1.48 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=292.939, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,0)[12]             : AIC=inf, Time=0.31 sec
#  ARIMA(1,1,3)(0,0,0)[12]             : AIC=289.909, Time=0.24 sec
#  ARIMA(0,1,3)(0,0,0)[12]             : AIC=294.936, Time=0.08 sec
#  ARIMA(2,1,3)(0,0,0)[12]             : AIC=290.519, Time=0.37 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[12]
# Total fit time: 10.886 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=211.444, Time=1.24 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=263.367, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=245.183, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=246.839, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=261.477, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=1.01 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=211.220, Time=2.88 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=2.84 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=213.493, Time=3.98 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=2.74 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=2.60 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=213.452, Time=1.79 sec
#  ARIMA(3,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=2.74 sec
#  ARIMA(2,1,3)(2,0,1)[12] intercept   : AIC=213.435, Time=2.56 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=230.645, Time=0.90 sec
#  ARIMA(1,1,3)(2,0,1)[12] intercept   : AIC=211.635, Time=2.22 sec
#  ARIMA(3,1,1)(2,0,1)[12] intercept   : AIC=211.551, Time=2.35 sec
#  ARIMA(3,1,3)(2,0,1)[12] intercept   : AIC=inf, Time=2.85 sec
#  ARIMA(2,1,2)(2,0,1)[12]             : AIC=211.443, Time=1.11 sec
#
# Best model:  ARIMA(2,1,2)(2,0,1)[12] intercept
# Total fit time: 35.336 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-95.681, Time=1.20 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-12.908, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-85.001, Time=0.28 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-68.664, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-14.792, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=-67.189, Time=0.76 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=-85.157, Time=1.02 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=-93.841, Time=2.35 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=-93.676, Time=2.28 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=-40.749, Time=0.45 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=-71.202, Time=1.97 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=-92.186, Time=2.12 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=-92.446, Time=3.38 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=-97.298, Time=1.32 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=-66.343, Time=0.95 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=-86.249, Time=0.70 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=-95.287, Time=2.39 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=-95.284, Time=2.32 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-34.604, Time=0.33 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=-72.131, Time=1.26 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=-92.265, Time=1.49 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=-93.831, Time=2.47 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=-99.231, Time=1.76 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=-68.121, Time=0.55 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=-88.150, Time=0.40 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=-97.234, Time=1.72 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=-97.235, Time=1.80 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=-36.244, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=-73.937, Time=0.84 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=-94.215, Time=0.75 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=-95.770, Time=2.10 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=-96.671, Time=0.55 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=-97.325, Time=1.16 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=-98.016, Time=0.84 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=-96.655, Time=1.53 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=-101.217, Time=0.42 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=-70.117, Time=0.25 sec
#  ARIMA(0,1,2)(1,0,0)[12]             : AIC=-90.146, Time=0.27 sec
#  ARIMA(0,1,2)(2,0,1)[12]             : AIC=-99.220, Time=0.98 sec
#  ARIMA(0,1,2)(1,0,2)[12]             : AIC=-99.221, Time=1.21 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=-38.200, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,2)[12]             : AIC=-75.919, Time=0.81 sec
#  ARIMA(0,1,2)(2,0,0)[12]             : AIC=-96.193, Time=0.44 sec
#  ARIMA(0,1,2)(2,0,2)[12]             : AIC=-97.775, Time=1.49 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=-98.650, Time=0.45 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=-99.283, Time=0.69 sec
#  ARIMA(0,1,3)(1,0,1)[12]             : AIC=-99.309, Time=0.71 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=-100.002, Time=0.48 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=inf, Time=1.13 sec
#
# Best model:  ARIMA(0,1,2)(1,0,1)[12]
# Total fit time: 53.013 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-287.589, Time=1.37 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-200.128, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-282.095, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-273.619, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-198.459, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=-286.019, Time=1.05 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=-295.987, Time=3.01 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=-296.040, Time=2.20 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=-307.332, Time=1.70 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=-296.265, Time=0.80 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=-308.867, Time=2.09 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=-308.967, Time=1.11 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=-292.221, Time=0.79 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=-306.593, Time=2.22 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-285.762, Time=0.25 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=-301.548, Time=1.96 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=-306.987, Time=2.97 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=-310.243, Time=1.58 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=-293.848, Time=0.42 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=-297.888, Time=0.42 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=-310.451, Time=2.04 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=-308.603, Time=1.50 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=-307.735, Time=3.69 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=-310.605, Time=1.83 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=-302.850, Time=1.21 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=-288.799, Time=1.66 sec
#  ARIMA(0,1,3)(1,0,2)[12] intercept   : AIC=-309.302, Time=2.14 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=-307.287, Time=1.76 sec
#  ARIMA(1,1,3)(1,0,2)[12] intercept   : AIC=-307.099, Time=3.76 sec
#  ARIMA(0,1,2)(1,0,2)[12]             : AIC=-312.189, Time=2.40 sec
#  ARIMA(0,1,2)(0,0,2)[12]             : AIC=-304.020, Time=1.49 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=-311.898, Time=0.72 sec
#  ARIMA(0,1,2)(2,0,2)[12]             : AIC=-310.044, Time=2.93 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=-295.041, Time=0.32 sec
#  ARIMA(0,1,2)(2,0,1)[12]             : AIC=-312.033, Time=2.18 sec
#  ARIMA(0,1,1)(1,0,2)[12]             : AIC=-290.007, Time=1.27 sec
#  ARIMA(1,1,2)(1,0,2)[12]             : AIC=-311.381, Time=2.01 sec
#  ARIMA(0,1,3)(1,0,2)[12]             : AIC=-311.043, Time=2.04 sec
#  ARIMA(1,1,1)(1,0,2)[12]             : AIC=-310.399, Time=1.74 sec
#  ARIMA(1,1,3)(1,0,2)[12]             : AIC=-309.462, Time=2.26 sec
#
# Best model:  ARIMA(0,1,2)(1,0,2)[12]
# Total fit time: 64.731 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-659.253, Time=1.22 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-561.126, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-655.809, Time=0.40 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-619.795, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-556.619, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=-643.020, Time=0.61 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=-651.756, Time=0.99 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=-656.211, Time=2.22 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=-653.259, Time=2.03 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=-630.180, Time=0.40 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=-651.935, Time=1.80 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=-657.878, Time=1.98 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=-655.661, Time=2.51 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=-663.753, Time=1.47 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=-644.924, Time=0.37 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=-653.929, Time=0.87 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=-658.410, Time=1.85 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=-655.968, Time=2.02 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=-632.048, Time=0.38 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=-653.778, Time=1.80 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=-660.262, Time=1.88 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=-659.415, Time=2.26 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=-652.640, Time=0.91 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=-663.560, Time=0.96 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=-662.022, Time=1.25 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=-624.873, Time=0.84 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=-653.691, Time=1.16 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=-661.171, Time=1.29 sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=-656.663, Time=1.42 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=-665.874, Time=0.94 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=-646.576, Time=0.26 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=-655.796, Time=0.50 sec
#  ARIMA(1,1,2)(2,0,1)[12]             : AIC=-660.758, Time=1.46 sec
#  ARIMA(1,1,2)(1,0,2)[12]             : AIC=-658.860, Time=1.69 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=-633.180, Time=0.39 sec
#  ARIMA(1,1,2)(0,0,2)[12]             : AIC=-655.658, Time=1.04 sec
#  ARIMA(1,1,2)(2,0,0)[12]             : AIC=-662.335, Time=1.24 sec
#  ARIMA(1,1,2)(2,0,2)[12]             : AIC=-661.547, Time=1.74 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=-654.795, Time=0.74 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=-666.625, Time=0.71 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=-647.539, Time=0.37 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=-655.696, Time=0.14 sec
#  ARIMA(1,1,1)(2,0,1)[12]             : AIC=-661.675, Time=1.28 sec
#  ARIMA(1,1,1)(1,0,2)[12]             : AIC=-662.263, Time=1.48 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=-634.960, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,2)[12]             : AIC=-655.835, Time=1.33 sec
#  ARIMA(1,1,1)(2,0,0)[12]             : AIC=-663.011, Time=0.69 sec
#  ARIMA(1,1,1)(2,0,2)[12]             : AIC=-662.429, Time=1.59 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=-626.013, Time=0.66 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=-668.618, Time=0.60 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=-649.467, Time=0.26 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=-657.584, Time=0.16 sec
#  ARIMA(1,1,0)(2,0,1)[12]             : AIC=-665.442, Time=1.05 sec
#  ARIMA(1,1,0)(1,0,2)[12]             : AIC=-661.945, Time=1.19 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=-636.934, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,2)[12]             : AIC=-657.725, Time=0.87 sec
#  ARIMA(1,1,0)(2,0,0)[12]             : AIC=-664.865, Time=0.79 sec
#  ARIMA(1,1,0)(2,0,2)[12]             : AIC=-663.314, Time=1.37 sec
#  ARIMA(0,1,0)(1,0,1)[12]             : AIC=-574.354, Time=0.74 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=-664.662, Time=0.63 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=-666.421, Time=0.96 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=-666.543, Time=0.78 sec
#
# Best model:  ARIMA(1,1,0)(1,0,1)[12]
# Total fit time: 63.176 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-56.793, Time=2.02 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=303.869, Time=0.04 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=7.052, Time=0.58 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=170.390, Time=0.37 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=328.524, Time=0.03 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-57.819, Time=1.57 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-22.527, Time=0.49 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-56.810, Time=5.15 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-51.905, Time=1.76 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=-54.794, Time=4.88 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-58.650, Time=1.90 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-21.450, Time=0.62 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-57.630, Time=1.67 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-57.602, Time=2.51 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-52.690, Time=1.08 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=-55.634, Time=4.67 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=77.788, Time=0.78 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-52.618, Time=1.50 sec
#  ARIMA(1,0,3)(0,1,1)[12] intercept   : AIC=-57.890, Time=1.22 sec
#  ARIMA(0,0,3)(0,1,1)[12] intercept   : AIC=21.353, Time=0.91 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-59.616, Time=0.89 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=-24.149, Time=0.24 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=-58.607, Time=1.64 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=-58.626, Time=2.39 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=-53.505, Time=0.95 sec
#  ARIMA(2,0,1)(1,1,2)[12] intercept   : AIC=-56.580, Time=3.02 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-55.047, Time=1.07 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-57.533, Time=1.65 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-59.938, Time=0.80 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=-23.775, Time=0.33 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=-58.940, Time=1.76 sec
#  ARIMA(3,0,0)(0,1,2)[12] intercept   : AIC=-58.980, Time=2.40 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=-53.950, Time=0.91 sec
#  ARIMA(3,0,0)(1,1,2)[12] intercept   : AIC=-56.828, Time=2.89 sec
#  ARIMA(4,0,0)(0,1,1)[12] intercept   : AIC=-57.976, Time=1.24 sec
#  ARIMA(4,0,1)(0,1,1)[12] intercept   : AIC=-55.958, Time=1.57 sec
#  ARIMA(3,0,0)(0,1,1)[12]             : AIC=-58.534, Time=0.93 sec
#
# Best model:  ARIMA(3,0,0)(0,1,1)[12] intercept
# Total fit time: 59.075 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=2.04 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=303.040, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=77.501, Time=0.83 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=308.474, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=116.065, Time=0.09 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=62.316, Time=0.97 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=60.284, Time=2.05 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(1,0,0)(2,1,2)[12] intercept   : AIC=60.420, Time=2.27 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=2.51 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=286.268, Time=0.66 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=12.824, Time=2.79 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=12.627, Time=1.48 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=27.958, Time=0.54 sec
#  ARIMA(3,0,0)(2,1,0)[12] intercept   : AIC=3.043, Time=2.03 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=18.268, Time=0.65 sec
#  ARIMA(3,0,0)(2,1,1)[12] intercept   : AIC=2.336, Time=3.73 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(3,0,0)(2,1,2)[12] intercept   : AIC=inf, Time=4.18 sec
#  ARIMA(3,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=1.65 sec
#  ARIMA(4,0,0)(2,1,1)[12] intercept   : AIC=4.333, Time=3.57 sec
#  ARIMA(3,0,1)(2,1,1)[12] intercept   : AIC=4.321, Time=4.32 sec
#  ARIMA(2,0,1)(2,1,1)[12] intercept   : AIC=inf, Time=3.10 sec
#  ARIMA(4,0,1)(2,1,1)[12] intercept   : AIC=inf, Time=4.08 sec
#  ARIMA(3,0,0)(2,1,1)[12]             : AIC=3.731, Time=3.34 sec
#
# Best model:  ARIMA(3,0,0)(2,1,1)[12] intercept
# Total fit time: 52.710 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=-260.621, Time=2.35 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=-81.410, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1327.006, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=-406.282, Time=0.88 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=-392.215, Time=0.50 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=-411.926, Time=1.65 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=3.69 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=-415.643, Time=1.84 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=-410.330, Time=0.41 sec
#  ARIMA(1,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=3.27 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.54 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=inf, Time=1.31 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=-416.035, Time=1.44 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=-410.230, Time=0.59 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=-283.527, Time=2.39 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.64 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=-370.909, Time=0.59 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=-415.923, Time=1.73 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=-409.523, Time=1.12 sec
#  ARIMA(1,0,1)(0,0,2)[12]             : AIC=-392.527, Time=0.63 sec
#
# Best model:  ARIMA(1,0,1)(0,0,2)[12] intercept
# Total fit time: 31.054 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=189.164, Time=1.21 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=366.686, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=291.312, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=364.700, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=296.604, Time=1.06 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=202.972, Time=1.17 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=174.621, Time=2.35 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=176.815, Time=2.42 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=190.023, Time=2.64 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=2.18 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=4.59 sec
#  ARIMA(3,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=2.38 sec
#  ARIMA(2,1,3)(2,0,1)[12] intercept   : AIC=149.677, Time=2.66 sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=162.023, Time=1.40 sec
#  ARIMA(2,1,3)(2,0,0)[12] intercept   : AIC=171.121, Time=2.31 sec
#  ARIMA(2,1,3)(2,0,2)[12] intercept   : AIC=inf, Time=3.06 sec
#  ARIMA(2,1,3)(1,0,0)[12] intercept   : AIC=189.452, Time=1.22 sec
#  ARIMA(2,1,3)(1,0,2)[12] intercept   : AIC=166.001, Time=2.59 sec
#  ARIMA(1,1,3)(2,0,1)[12] intercept   : AIC=153.245, Time=2.18 sec
#  ARIMA(3,1,3)(2,0,1)[12] intercept   : AIC=154.021, Time=2.98 sec
#  ARIMA(2,1,4)(2,0,1)[12] intercept   : AIC=162.505, Time=2.55 sec
#  ARIMA(1,1,4)(2,0,1)[12] intercept   : AIC=165.651, Time=2.48 sec
#  ARIMA(3,1,4)(2,0,1)[12] intercept   : AIC=162.844, Time=3.14 sec
#  ARIMA(2,1,3)(2,0,1)[12]             : AIC=inf, Time=2.89 sec
#
# Best model:  ARIMA(2,1,3)(2,0,1)[12] intercept
# Total fit time: 52.328 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=473.884, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=414.574, Time=0.69 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=418.103, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1312.604, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=413.705, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=414.776, Time=0.16 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=413.344, Time=0.10 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=420.720, Time=0.94 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=414.370, Time=0.29 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=411.730, Time=0.11 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=412.709, Time=1.12 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=412.728, Time=0.67 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=413.142, Time=0.14 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=413.269, Time=0.47 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=416.004, Time=0.28 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=415.138, Time=0.52 sec
#  ARIMA(3,0,0)(0,0,0)[12]             : AIC=inf, Time=0.05 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[12] intercept
# Total fit time: 10.286 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=2.74 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-330.706, Time=0.08 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-624.726, Time=0.83 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.97 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-97.023, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=-598.575, Time=0.06 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=-631.270, Time=4.17 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=-632.788, Time=5.17 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(1,0,0)(2,1,2)[12] intercept   : AIC=-635.251, Time=2.61 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=3.64 sec
#  ARIMA(0,0,0)(2,1,2)[12] intercept   : AIC=inf, Time=2.66 sec
#  ARIMA(2,0,0)(2,1,2)[12] intercept   : AIC=-686.282, Time=6.63 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=3.97 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=-683.887, Time=4.02 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=2.19 sec
#  ARIMA(3,0,0)(2,1,2)[12] intercept   : AIC=-693.338, Time=5.56 sec
#  ARIMA(3,0,0)(1,1,2)[12] intercept   : AIC=-690.579, Time=6.97 sec
#  ARIMA(3,0,0)(2,1,1)[12] intercept   : AIC=-690.437, Time=4.62 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=-611.374, Time=1.45 sec
#  ARIMA(4,0,0)(2,1,2)[12] intercept   : AIC=-691.207, Time=6.87 sec
#  ARIMA(3,0,1)(2,1,2)[12] intercept   : AIC=-687.488, Time=9.21 sec
#  ARIMA(2,0,1)(2,1,2)[12] intercept   : AIC=-690.512, Time=7.15 sec
#  ARIMA(4,0,1)(2,1,2)[12] intercept   : AIC=-692.579, Time=6.96 sec
#  ARIMA(3,0,0)(2,1,2)[12]             : AIC=-678.149, Time=3.15 sec
#
# Best model:  ARIMA(3,0,0)(2,1,2)[12] intercept
# Total fit time: 93.227 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=-697.645, Time=1.52 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-562.441, Time=0.08 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-674.742, Time=0.45 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=-675.250, Time=1.24 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=-704.776, Time=2.79 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=-672.579, Time=0.17 sec
#  ARIMA(2,1,2)(0,1,2)[12]             : AIC=-699.976, Time=2.42 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=-701.102, Time=1.94 sec
#  ARIMA(2,1,2)(1,1,2)[12]             : AIC=-699.418, Time=4.16 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=-702.793, Time=1.05 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=-704.915, Time=3.00 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=-671.727, Time=0.22 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=-699.339, Time=2.16 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=-697.546, Time=1.37 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=-701.492, Time=1.45 sec
#  ARIMA(2,1,1)(1,1,2)[12]             : AIC=-701.413, Time=4.66 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=-700.809, Time=2.44 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=-701.015, Time=1.05 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=-700.703, Time=2.16 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=-682.117, Time=2.01 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=-705.352, Time=0.68 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=-673.950, Time=0.25 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=-698.250, Time=0.67 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=-707.188, Time=3.97 sec
#  ARIMA(3,1,0)(1,1,2)[12]             : AIC=-699.951, Time=2.19 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=-698.969, Time=1.64 sec
#  ARIMA(4,1,0)(0,1,2)[12]             : AIC=-704.256, Time=2.09 sec
#  ARIMA(3,1,1)(0,1,2)[12]             : AIC=-700.301, Time=8.39 sec
#  ARIMA(4,1,1)(0,1,2)[12]             : AIC=-702.048, Time=6.61 sec
#  ARIMA(3,1,0)(0,1,2)[12] intercept   : AIC=-701.793, Time=3.73 sec
#
# Best model:  ARIMA(3,1,0)(0,1,2)[12]
# Total fit time: 66.579 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=304.886, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=197.818, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1286.328, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=248.240, Time=0.05 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=186.772, Time=0.51 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=188.555, Time=1.66 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=269.265, Time=0.29 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=133.320, Time=1.21 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=148.108, Time=0.40 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=106.842, Time=2.07 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=127.053, Time=1.29 sec
#  ARIMA(1,0,1)(2,0,2)[12] intercept   : AIC=119.883, Time=2.17 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=1.96 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=153.772, Time=1.80 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=1.22 sec
#  ARIMA(1,0,2)(1,0,2)[12] intercept   : AIC=123.977, Time=3.00 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=271.270, Time=1.47 sec
#  ARIMA(0,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=2.37 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=1.95 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=2.41 sec
#  ARIMA(1,0,1)(1,0,2)[12]             : AIC=62.765, Time=1.46 sec
#  ARIMA(1,0,1)(0,0,2)[12]             : AIC=153.084, Time=0.77 sec
#  ARIMA(1,0,1)(1,0,1)[12]             : AIC=62.228, Time=0.47 sec
#  ARIMA(1,0,1)(0,0,1)[12]             : AIC=167.604, Time=0.15 sec
#  ARIMA(1,0,1)(1,0,0)[12]             : AIC=140.530, Time=0.21 sec
#  ARIMA(1,0,1)(2,0,1)[12]             : AIC=62.899, Time=0.72 sec
#  ARIMA(1,0,1)(0,0,0)[12]             : AIC=224.885, Time=0.08 sec
#  ARIMA(1,0,1)(2,0,0)[12]             : AIC=107.774, Time=1.04 sec
#  ARIMA(1,0,1)(2,0,2)[12]             : AIC=63.389, Time=1.69 sec
#  ARIMA(0,0,1)(1,0,1)[12]             : AIC=261.903, Time=0.93 sec
#  ARIMA(1,0,0)(1,0,1)[12]             : AIC=inf, Time=0.61 sec
#  ARIMA(2,0,1)(1,0,1)[12]             : AIC=62.460, Time=0.96 sec
#  ARIMA(1,0,2)(1,0,1)[12]             : AIC=59.550, Time=0.88 sec
#  ARIMA(1,0,2)(0,0,1)[12]             : AIC=169.596, Time=0.50 sec
#  ARIMA(1,0,2)(1,0,0)[12]             : AIC=137.879, Time=0.50 sec
#  ARIMA(1,0,2)(2,0,1)[12]             : AIC=60.932, Time=0.88 sec
#  ARIMA(1,0,2)(1,0,2)[12]             : AIC=60.796, Time=2.57 sec
#  ARIMA(1,0,2)(0,0,0)[12]             : AIC=225.456, Time=0.17 sec
#  ARIMA(1,0,2)(0,0,2)[12]             : AIC=155.054, Time=1.04 sec
#  ARIMA(1,0,2)(2,0,0)[12]             : AIC=67.926, Time=1.43 sec
#  ARIMA(1,0,2)(2,0,2)[12]             : AIC=inf, Time=2.81 sec
#  ARIMA(0,0,2)(1,0,1)[12]             : AIC=inf, Time=2.00 sec
#  ARIMA(2,0,2)(1,0,1)[12]             : AIC=51.093, Time=1.24 sec
#  ARIMA(2,0,2)(0,0,1)[12]             : AIC=170.571, Time=0.95 sec
#  ARIMA(2,0,2)(1,0,0)[12]             : AIC=88.314, Time=0.90 sec
#  ARIMA(2,0,2)(2,0,1)[12]             : AIC=53.421, Time=1.87 sec
#  ARIMA(2,0,2)(1,0,2)[12]             : AIC=53.173, Time=2.09 sec
#  ARIMA(2,0,2)(0,0,0)[12]             : AIC=inf, Time=0.37 sec
#  ARIMA(2,0,2)(0,0,2)[12]             : AIC=156.626, Time=1.58 sec
#  ARIMA(2,0,2)(2,0,0)[12]             : AIC=67.474, Time=1.61 sec
#  ARIMA(2,0,2)(2,0,2)[12]             : AIC=inf, Time=2.55 sec
#  ARIMA(3,0,2)(1,0,1)[12]             : AIC=52.631, Time=1.25 sec
#  ARIMA(2,0,3)(1,0,1)[12]             : AIC=53.073, Time=1.47 sec
#  ARIMA(1,0,3)(1,0,1)[12]             : AIC=64.371, Time=1.30 sec
#  ARIMA(3,0,1)(1,0,1)[12]             : AIC=48.465, Time=1.60 sec
#  ARIMA(3,0,1)(0,0,1)[12]             : AIC=171.153, Time=0.63 sec
#  ARIMA(3,0,1)(1,0,0)[12]             : AIC=134.356, Time=0.94 sec
#  ARIMA(3,0,1)(2,0,1)[12]             : AIC=49.970, Time=2.79 sec
#  ARIMA(3,0,1)(1,0,2)[12]             : AIC=49.790, Time=2.37 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : AIC=228.276, Time=0.24 sec
#  ARIMA(3,0,1)(0,0,2)[12]             : AIC=156.513, Time=1.41 sec
#  ARIMA(3,0,1)(2,0,0)[12]             : AIC=87.606, Time=2.02 sec
#  ARIMA(3,0,1)(2,0,2)[12]             : AIC=inf, Time=4.15 sec
#  ARIMA(3,0,0)(1,0,1)[12]             : AIC=57.168, Time=0.84 sec
#  ARIMA(4,0,1)(1,0,1)[12]             : AIC=48.541, Time=1.41 sec
#  ARIMA(2,0,0)(1,0,1)[12]             : AIC=61.177, Time=0.55 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : AIC=57.030, Time=1.16 sec
#  ARIMA(4,0,2)(1,0,1)[12]             : AIC=inf, Time=3.03 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.57 sec
#
# Best model:  ARIMA(3,0,1)(1,0,1)[12]
# Total fit time: 93.266 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=133.716, Time=1.15 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=215.121, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=173.874, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=182.966, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=213.218, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=134.943, Time=2.35 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=136.543, Time=2.47 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=2.04 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=134.991, Time=1.93 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=2.57 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=128.220, Time=1.44 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=130.309, Time=1.95 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=132.061, Time=2.55 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=1.82 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=134.909, Time=1.73 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=2.46 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=151.245, Time=0.69 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=145.274, Time=0.68 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=134.848, Time=1.28 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=154.594, Time=0.57 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=144.348, Time=0.98 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=129.531, Time=0.62 sec
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 37.848 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=-409.181, Time=1.55 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-298.839, Time=0.05 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-411.727, Time=0.34 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=-389.491, Time=0.55 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=-364.255, Time=0.07 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=-413.614, Time=0.82 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=-414.801, Time=2.33 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=-415.702, Time=1.70 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=inf, Time=1.21 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : AIC=inf, Time=2.65 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : AIC=inf, Time=2.10 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=-412.275, Time=5.43 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=inf, Time=1.03 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=-413.873, Time=1.62 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=-413.950, Time=1.39 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=inf, Time=1.68 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=-412.012, Time=1.76 sec
#  ARIMA(1,1,0)(1,1,1)[12] intercept   : AIC=-413.945, Time=1.39 sec
#
# Best model:  ARIMA(1,1,0)(1,1,1)[12]
# Total fit time: 27.718 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=83.819, Time=0.08 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-178.217, Time=0.60 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-42.109, Time=1.12 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=103.537, Time=0.04 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=-161.537, Time=0.22 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=-184.071, Time=2.07 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=3.10 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.50 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=83.521, Time=0.62 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=-220.109, Time=2.69 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-210.462, Time=1.18 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=3.14 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.62 sec
#  ARIMA(3,0,0)(2,1,0)[12] intercept   : AIC=-218.104, Time=3.65 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=-218.138, Time=3.42 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=-210.470, Time=2.52 sec
#  ARIMA(3,0,1)(2,1,0)[12] intercept   : AIC=-216.267, Time=3.58 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : AIC=-219.889, Time=1.65 sec
#
# Best model:  ARIMA(2,0,0)(2,1,0)[12] intercept
# Total fit time: 35.095 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=86.378, Time=1.36 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=295.435, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=225.871, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=293.883, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=1.18 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=1.22 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=75.152, Time=2.81 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=89.851, Time=3.06 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=3.16 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=78.004, Time=2.76 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=72.949, Time=2.82 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=69.893, Time=1.19 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=72.051, Time=2.45 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=284.283, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=88.022, Time=2.02 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=2.89 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=71.253, Time=0.98 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=72.221, Time=1.07 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=76.852, Time=1.49 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.12 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=81.705, Time=1.30 sec
# ...
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-591.171, Time=1.16 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-667.200, Time=2.89 sec
#  ARIMA(3,0,2)(0,1,1)[12] intercept   : AIC=-663.089, Time=1.68 sec
#  ARIMA(2,0,1)(0,1,1)[12]             : AIC=-654.570, Time=1.09 sec
#
# Best model:  ARIMA(2,0,1)(0,1,1)[12] intercept
# Total fit time: 82.708 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-21.296, Time=2.32 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=228.289, Time=0.08 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=16.135, Time=0.50 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.90 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=232.344, Time=0.06 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-21.940, Time=1.07 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=20.991, Time=0.44 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=inf, Time=4.02 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-7.456, Time=1.35 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=-20.163, Time=4.50 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-23.940, Time=0.96 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=20.101, Time=0.54 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-22.555, Time=1.68 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=inf, Time=2.11 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-8.606, Time=0.63 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=-21.213, Time=3.83 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=23.584, Time=1.01 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-20.275, Time=0.82 sec
#  ARIMA(1,0,3)(0,1,1)[12] intercept   : AIC=-21.940, Time=1.32 sec
#  ARIMA(0,0,3)(0,1,1)[12] intercept   : AIC=3.139, Time=1.36 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-24.186, Time=0.97 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=21.521, Time=0.25 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=-23.302, Time=1.34 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=inf, Time=3.68 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=-9.337, Time=0.81 sec
#  ARIMA(2,0,1)(1,1,2)[12] intercept   : AIC=-22.195, Time=3.43 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-25.803, Time=1.04 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=19.972, Time=0.11 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-24.920, Time=1.22 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=inf, Time=1.62 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-10.766, Time=0.56 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=-23.919, Time=3.04 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=4.232, Time=0.47 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-24.197, Time=1.10 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-22.190, Time=1.75 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-20.555, Time=0.52 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 51.468 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=424.161, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=289.966, Time=0.19 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=348.376, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=422.343, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=425.145, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=348.484, Time=0.17 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=1.71 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=287.966, Time=0.15 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=346.679, Time=0.19 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=1.50 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=289.966, Time=0.21 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(0,1,0)(1,0,0)[12]             : AIC=285.985, Time=0.07 sec
#  ARIMA(0,1,0)(2,0,0)[12]             : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,0)(1,0,1)[12]             : AIC=287.112, Time=0.46 sec
#  ARIMA(0,1,0)(0,0,1)[12]             : AIC=344.735, Time=0.11 sec
#  ARIMA(0,1,0)(2,0,1)[12]             : AIC=inf, Time=0.92 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=287.985, Time=0.13 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=287.985, Time=0.12 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=282.033, Time=0.36 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=411.842, Time=0.09 sec
#  ARIMA(1,1,1)(2,0,0)[12]             : AIC=282.907, Time=1.40 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=inf, Time=1.09 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=338.789, Time=0.33 sec
#  ARIMA(1,1,1)(2,0,1)[12]             : AIC=inf, Time=2.38 sec
#  ARIMA(2,1,1)(1,0,0)[12]             : AIC=283.274, Time=0.38 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=283.216, Time=0.38 sec
#  ARIMA(0,1,2)(1,0,0)[12]             : AIC=288.244, Time=0.19 sec
#  ARIMA(2,1,0)(1,0,0)[12]             : AIC=288.471, Time=0.25 sec
#  ARIMA(2,1,2)(1,0,0)[12]             : AIC=285.167, Time=0.86 sec
#
# Best model:  ARIMA(1,1,1)(1,0,0)[12]
# Total fit time: 19.342 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=-285.101, Time=1.93 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-214.501, Time=0.07 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-274.982, Time=0.52 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=-284.320, Time=1.18 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=-287.124, Time=1.87 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=inf, Time=0.67 sec
#  ARIMA(2,1,2)(0,1,2)[12]             : AIC=-285.231, Time=3.52 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=-271.459, Time=1.23 sec
#  ARIMA(2,1,2)(1,1,2)[12]             : AIC=inf, Time=4.02 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=-287.072, Time=1.37 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=-288.521, Time=1.65 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=-253.512, Time=0.34 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=-285.716, Time=1.68 sec
#  ARIMA(2,1,1)(0,1,2)[12]             : AIC=-286.529, Time=3.59 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=-273.866, Time=1.12 sec
#  ARIMA(2,1,1)(1,1,2)[12]             : AIC=inf, Time=3.11 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=-288.774, Time=1.44 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=-255.161, Time=0.12 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=-286.807, Time=1.16 sec
#  ARIMA(1,1,1)(0,1,2)[12]             : AIC=-286.847, Time=2.95 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=-273.911, Time=0.79 sec
#  ARIMA(1,1,1)(1,1,2)[12]             : AIC=inf, Time=3.58 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=-290.160, Time=0.80 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=-255.004, Time=0.09 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=-288.200, Time=0.85 sec
#  ARIMA(1,1,0)(0,1,2)[12]             : AIC=-288.222, Time=1.25 sec
#  ARIMA(1,1,0)(1,1,2)[12]             : AIC=inf, Time=2.76 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=-257.027, Time=0.18 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=-288.972, Time=1.04 sec
#  ARIMA(1,1,0)(0,1,1)[12] intercept   : AIC=-287.873, Time=1.43 sec
#
# Best model:  ARIMA(1,1,0)(0,1,1)[12]
# Total fit time: 46.377 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.73 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=292.477, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=94.255, Time=0.80 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=186.678, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1284.687, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=196.110, Time=0.09 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=88.737, Time=1.96 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=168.536, Time=2.09 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=83.510, Time=1.14 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=148.055, Time=0.54 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=1.80 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=inf, Time=1.63 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=2.34 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=277.445, Time=1.19 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=113.183, Time=1.25 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.41 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=196.173, Time=1.00 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=183.254, Time=1.44 sec
#  ARIMA(1,0,0)(1,0,1)[12]             : AIC=76.619, Time=0.62 sec
#  ARIMA(1,0,0)(0,0,1)[12]             : AIC=166.052, Time=0.21 sec
#  ARIMA(1,0,0)(1,0,0)[12]             : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,0)(2,0,1)[12]             : AIC=78.347, Time=1.12 sec
#  ARIMA(1,0,0)(1,0,2)[12]             : AIC=78.116, Time=1.34 sec
#  ARIMA(1,0,0)(0,0,0)[12]             : AIC=inf, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,2)[12]             : AIC=inf, Time=0.98 sec
#  ARIMA(1,0,0)(2,0,0)[12]             : AIC=inf, Time=1.53 sec
#  ARIMA(1,0,0)(2,0,2)[12]             : AIC=inf, Time=2.77 sec
#  ARIMA(0,0,0)(1,0,1)[12]             : AIC=414.293, Time=0.35 sec
#  ARIMA(2,0,0)(1,0,1)[12]             : AIC=55.269, Time=0.53 sec
#  ARIMA(2,0,0)(0,0,1)[12]             : AIC=166.575, Time=0.15 sec
#  ARIMA(2,0,0)(1,0,0)[12]             : AIC=inf, Time=0.55 sec
#  ARIMA(2,0,0)(2,0,1)[12]             : AIC=56.936, Time=1.81 sec
#  ARIMA(2,0,0)(1,0,2)[12]             : AIC=56.586, Time=3.37 sec
#  ARIMA(2,0,0)(0,0,0)[12]             : AIC=inf, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,2)[12]             : AIC=inf, Time=1.14 sec
#  ARIMA(2,0,0)(2,0,0)[12]             : AIC=inf, Time=1.00 sec
#  ARIMA(2,0,0)(2,0,2)[12]             : AIC=inf, Time=2.80 sec
#  ARIMA(3,0,0)(1,0,1)[12]             : AIC=53.076, Time=0.47 sec
#  ARIMA(3,0,0)(0,0,1)[12]             : AIC=160.389, Time=0.18 sec
#  ARIMA(3,0,0)(1,0,0)[12]             : AIC=inf, Time=0.86 sec
#  ARIMA(3,0,0)(2,0,1)[12]             : AIC=54.875, Time=1.89 sec
#  ARIMA(3,0,0)(1,0,2)[12]             : AIC=54.956, Time=2.25 sec
#  ARIMA(3,0,0)(0,0,0)[12]             : AIC=inf, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,2)[12]             : AIC=inf, Time=1.40 sec
#  ARIMA(3,0,0)(2,0,0)[12]             : AIC=inf, Time=1.90 sec
#  ARIMA(3,0,0)(2,0,2)[12]             : AIC=inf, Time=3.45 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : AIC=57.571, Time=1.81 sec
#  ARIMA(3,0,1)(1,0,1)[12]             : AIC=54.878, Time=0.64 sec
#  ARIMA(2,0,1)(1,0,1)[12]             : AIC=inf, Time=1.18 sec
#  ARIMA(4,0,1)(1,0,1)[12]             : AIC=58.013, Time=1.32 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=127.818, Time=1.86 sec
#
# Best model:  ARIMA(3,0,0)(1,0,1)[12]
# Total fit time: 60.756 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=139.887, Time=1.24 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=178.811, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=164.884, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=160.306, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=176.829, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=148.736, Time=0.71 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=147.442, Time=0.64 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=142.401, Time=2.56 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=141.524, Time=2.21 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=154.803, Time=0.35 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=150.167, Time=2.00 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=146.928, Time=1.52 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=2.52 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=141.737, Time=1.14 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=137.786, Time=1.18 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=147.095, Time=0.52 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=145.792, Time=0.40 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=139.773, Time=2.31 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=139.405, Time=2.07 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=153.134, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=148.517, Time=0.88 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=145.278, Time=1.77 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=2.25 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=150.761, Time=0.59 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=144.112, Time=0.69 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.60 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=155.490, Time=0.55 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=143.558, Time=0.72 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=141.391, Time=1.31 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=135.549, Time=0.63 sec
#  ARIMA(2,1,1)(0,0,1)[12]             : AIC=145.225, Time=0.25 sec
#  ARIMA(2,1,1)(1,0,0)[12]             : AIC=143.867, Time=0.27 sec
#  ARIMA(2,1,1)(2,0,1)[12]             : AIC=137.491, Time=1.29 sec
#  ARIMA(2,1,1)(1,0,2)[12]             : AIC=137.458, Time=1.11 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=151.547, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,2)[12]             : AIC=146.608, Time=0.83 sec
#  ARIMA(2,1,1)(2,0,0)[12]             : AIC=143.313, Time=0.48 sec
#  ARIMA(2,1,1)(2,0,2)[12]             : AIC=inf, Time=2.50 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=148.760, Time=0.48 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=142.115, Time=0.40 sec
#  ARIMA(3,1,1)(1,0,1)[12]             : AIC=137.191, Time=1.09 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=137.151, Time=0.89 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=153.491, Time=0.31 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=140.078, Time=0.61 sec
#  ARIMA(3,1,0)(1,0,1)[12]             : AIC=141.564, Time=0.40 sec
#  ARIMA(3,1,2)(1,0,1)[12]             : AIC=139.297, Time=1.15 sec
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12]
# Total fit time: 45.151 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=-729.796, Time=1.51 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-637.477, Time=0.16 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-730.306, Time=0.53 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=-691.989, Time=1.69 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=-698.689, Time=0.13 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=-738.680, Time=2.87 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=-734.286, Time=3.02 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=-723.438, Time=0.67 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=-671.690, Time=1.76 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=-741.816, Time=1.30 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=-740.252, Time=1.19 sec
#  ARIMA(2,1,0)(2,1,1)[12]             : AIC=-734.811, Time=2.52 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=-729.775, Time=0.64 sec
#  ARIMA(3,1,0)(2,1,0)[12]             : AIC=-744.145, Time=3.85 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=-735.581, Time=0.99 sec
#  ARIMA(3,1,0)(2,1,1)[12]             : AIC=-734.358, Time=3.18 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=-747.050, Time=1.78 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=-749.715, Time=1.26 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=-710.224, Time=0.33 sec
#  ARIMA(3,1,0)(0,1,2)[12]             : AIC=inf, Time=1.91 sec
#  ARIMA(3,1,0)(1,1,2)[12]             : AIC=inf, Time=6.32 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=-751.841, Time=1.43 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=-711.916, Time=0.32 sec
#  ARIMA(2,1,0)(0,1,2)[12]             : AIC=inf, Time=4.30 sec
#  ARIMA(2,1,0)(1,1,2)[12]             : AIC=inf, Time=2.63 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=-742.424, Time=0.76 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=-749.800, Time=1.28 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=-749.036, Time=0.79 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=-747.789, Time=0.94 sec
#  ARIMA(2,1,0)(0,1,1)[12] intercept   : AIC=-749.334, Time=0.46 sec
#
# Best model:  ARIMA(2,1,0)(0,1,1)[12]
# Total fit time: 50.577 seconds

# %%
# Las métricas son las siguientes
zone_dict
# Out:
# {'Alto Extremadura': {'params': (2, 1, 4, 0, 1, 1, 12),
#   'model': ARIMA(order=(2, 1, 4), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.5498978611124051,
#   'mae': 0.5479220006129307},
#  'Arturo Soria': {'params': (2, 1, 1, 1, 0, 1, 12),
#   'model': ARIMA(order=(2, 1, 1), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': -1.3277971855812098,
#   'mae': 1.6981305829103464},
#  'Avda de Moratalaz': {'params': (0, 1, 3, 0, 1, 1, 12),
#   'model': ARIMA(order=(0, 1, 3), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.4928746932714143,
#   'mae': 0.3938556354766532},
#  'Barajas Pueblo': {'params': (1, 1, 2, 0, 0, 0, 12),
#   'model': ARIMA(order=(1, 1, 2), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': -0.6659443228073489,
#   'mae': 0.6968281021563614},
#  'Barrio del Pilar': {'params': (2, 1, 2, 2, 0, 1, 12),
#   'model': ARIMA(order=(2, 1, 2), scoring_args={}, seasonal_order=(2, 0, 1, 12),
#         suppress_warnings=True),
#   'r2': -4.521611090914258,
#   'mae': 1.0707508386060833},
#  'Campo de las Naciones': {'params': (0, 1, 2, 1, 0, 1, 12),
#   'model': ARIMA(order=(0, 1, 2), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': -0.15279499151712583,
#   'mae': 0.6315077264790092},
#  'Carlos V': {'params': (0, 1, 2, 1, 0, 2, 12),
#   'model': ARIMA(order=(0, 1, 2), scoring_args={}, seasonal_order=(1, 0, 2, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.10759211000556435,
#   'mae': 0.861386581870599},
#  'Casa de Campo': {'params': (1, 1, 0, 1, 0, 1, 12),
#   'model': ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': -0.030691772768364878,
#   'mae': 0.798084740821148},
#  'Castellana': {'params': (3, 0, 0, 0, 1, 1, 12),
#   'model': ARIMA(order=(3, 0, 0), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#         suppress_warnings=True),
#   'r2': 0.8122400987774601,
#   'mae': 0.35830932423679485},
#  'Cuatro Caminos': {'params': (3, 0, 0, 2, 1, 1, 12),
#   'model': ARIMA(order=(3, 0, 0), scoring_args={}, seasonal_order=(2, 1, 1, 12),
#         suppress_warnings=True),
#   'r2': 0.4395243592722493,
#   'mae': 0.6248397489892703},
#  'Cuatro Vientos': {'params': (1, 0, 1, 0, 0, 2, 12),
#   'model': ARIMA(order=(1, 0, 1), scoring_args={}, seasonal_order=(0, 0, 2, 12),
#         suppress_warnings=True),
#   'r2': -0.2489144544216031,
#   'mae': 1.7174397023176664},
#  'El Pardo': {'params': (2, 1, 3, 2, 0, 1, 12),
#   'model': ARIMA(order=(2, 1, 3), scoring_args={}, seasonal_order=(2, 0, 1, 12),
#         suppress_warnings=True),
#   'r2': 0.20858697948297245,
#   'mae': 0.7635861886222151},
#  'Embajada': {'params': (3, 0, 0, 0, 0, 0, 12),
#   'model': ARIMA(order=(3, 0, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#         suppress_warnings=True),
#   'r2': -2.4297009886914736,
#   'mae': 1.635991115480468},
#  'Ensanche de Vallecas': {'params': (3, 0, 0, 2, 1, 2, 12),
#   'model': ARIMA(order=(3, 0, 0), scoring_args={}, seasonal_order=(2, 1, 2, 12),
#         suppress_warnings=True),
#   'r2': 0.48387125385017005,
#   'mae': 0.6921384668746627},
#  'Escuelas Aguirre': {'params': (3, 1, 0, 0, 1, 2, 12),
#   'model': ARIMA(order=(3, 1, 0), scoring_args={}, seasonal_order=(0, 1, 2, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.24523210748203217,
#   'mae': 0.8137119920169107},
#  'Farolillo': {'params': (3, 0, 1, 1, 0, 1, 12),
#   'model': ARIMA(order=(3, 0, 1), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.5283764551480534,
#   'mae': 0.3601478035483342},
#  'Glorieta Fdez. Ladreda': {'params': (2, 1, 1, 1, 0, 1, 12),
#   'model': ARIMA(order=(2, 1, 1), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True),
#   'r2': -1.3395914816645513,
#   'mae': 0.5212857088561061},
#  'Gregorio Marañón': {'params': (1, 1, 0, 1, 1, 1, 12),
#   'model': ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(1, 1, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.7250493983731978,
#   'mae': 0.3944858080586232},
#  'Méndez Álvaro': {'params': (2, 0, 0, 2, 1, 0, 12),
#   'model': ARIMA(order=(2, 0, 0), scoring_args={}, seasonal_order=(2, 1, 0, 12),
#         suppress_warnings=True),
#   'r2': 0.5260783247768822,
#   'mae': 0.6092079678395754},
#  'Paseo de Recoletos': {'params': (1, 1, 2, 1, 0, 1, 12),
#   'model': ARIMA(order=(1, 1, 2), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.21919118826423845,
#   'mae': 0.6088431163979092},
#  'Plaza Manuel Becerra': {'params': (0, 1, 3, 1, 0, 1, 12),
#   'model': ARIMA(order=(0, 1, 3), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.1834881110959955,
#   'mae': 0.399445119247666},
#  'Plaza de España': {'params': (1, 1, 2, 1, 0, 1, 12),
#   'model': ARIMA(order=(1, 1, 2), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': -1.3161469030880948,
#   'mae': 0.6766567929469213},
#  'Plaza del Carmen': {'params': (2, 0, 2, 0, 0, 1, 12),
#   'model': ARIMA(order=(2, 0, 2), scoring_args={}, seasonal_order=(0, 0, 1, 12),
#         suppress_warnings=True),
#   'r2': -0.025337322660118344,
#   'mae': 0.5944842590333776},
#  'Pza de Castilla': {'params': (1, 1, 2, 1, 0, 1, 12),
#   'model': ARIMA(order=(1, 1, 2), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True),
#   'r2': -0.7580977815422878,
#   'mae': 0.9068819203672237},
#  'Ramón y Cajal': {'params': (2, 0, 1, 0, 1, 1, 12),
#   'model': ARIMA(order=(2, 0, 1), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#         suppress_warnings=True),
#   'r2': 0.42848517421941534,
#   'mae': 1.2159750704021113},
#  'Sanchinarro': {'params': (2, 0, 0, 0, 1, 1, 12),
#   'model': ARIMA(order=(2, 0, 0), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#         suppress_warnings=True),
#   'r2': 0.46373375481261914,
#   'mae': 0.8753578456664758},
#  'Santa Eugenia': {'params': (1, 1, 1, 1, 0, 0, 12),
#   'model': ARIMA(order=(1, 1, 1), scoring_args={}, seasonal_order=(1, 0, 0, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.09558171386541947,
#   'mae': 0.6821825633111851},
#  'Tres Olivos': {'params': (1, 1, 0, 0, 1, 1, 12),
#   'model': ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.5087995721011673,
#   'mae': 1.0416178806841039},
#  'Urbanización Embajada II': {'params': (3, 0, 0, 1, 0, 1, 12),
#   'model': ARIMA(order=(3, 0, 0), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.05893630232552405,
#   'mae': 0.6445485618465214},
#  'Vallecas': {'params': (2, 1, 1, 1, 0, 1, 12),
#   'model': ARIMA(order=(2, 1, 1), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': -1.9766780090282898,
#   'mae': 1.023339256464533},
#  'Villaverde': {'params': (2, 1, 0, 0, 1, 1, 12),
#   'model': ARIMA(order=(2, 1, 0), scoring_args={}, seasonal_order=(0, 1, 1, 12),
#         suppress_warnings=True, with_intercept=False),
#   'r2': 0.5142163323816775,
#   'mae': 0.8823030306750727}}

# %% [markdown]
# ### Predicción

# %%
# Se guardan las predicciones hasta abril de 2024 en un nuevo dataframe
# Se cogen solo aquellas zonas donde la r2 es superior a 0, es decir, que el modelo predice mejor que la media, lo que permite sacarle partido
df_predictions = pd.DataFrame({'A' : []})
for key, value in zone_dict.items():
    if value['r2'] > 0.0 and value['mae'] < 1.0:
        df_predictions[key] = value['model'].predict(start=len(df_train_smoothed), n_periods=len(df_test) * 2)

df_predictions = df_predictions.drop(columns='A')

df_predictions.head()
# Out:
#             Alto Extremadura  Avda de Moratalaz   Carlos V  Castellana  \
# 2022-01-01         55.088196          56.039734  65.550922   58.038311
# 2022-02-01         55.314389          56.226752  65.548379   58.323169
# 2022-03-01         54.558733          55.592104  65.457742   57.552492
# 2022-04-01         53.963860          55.457006  65.259008   56.732322
# 2022-05-01         53.763523          55.213552  65.096782   56.227088
#
#             Cuatro Caminos   El Pardo  Ensanche de Vallecas  Escuelas Aguirre  \
# 2022-01-01       59.428257  49.318611             57.810402         62.247797
# 2022-02-01       59.922721  49.867645             57.922619         62.512323
# 2022-03-01       58.759561  49.481867             56.860505         61.788953
# 2022-04-01       58.151328  49.333875             56.086105         61.179893
# 2022-05-01       58.445876  49.907934             56.038839         61.273844
#
#             Farolillo  Gregorio Marañón  Méndez Álvaro  Paseo de Recoletos  \
# 2022-01-01  49.273862         65.413009      48.003202           61.542336
# 2022-02-01  49.762482         65.772257      48.155795           61.827459
# 2022-03-01  49.707335         65.033565      47.951038           61.152156
# 2022-04-01  49.815722         63.763731      48.279867           60.742490
# 2022-05-01  50.521226         64.032981      48.951648           60.257450
#
#             Plaza Manuel Becerra  Sanchinarro  Santa Eugenia  \
# 2022-01-01             59.546655    54.529623      67.814183
# 2022-02-01             59.310967    54.264772      67.383233
# 2022-03-01             59.176837    52.655799      66.899180
# 2022-04-01             58.761739    51.785702      66.448912
# 2022-05-01             58.723641    51.469982      66.481257
#
#             Urbanización Embajada II  Villaverde
# 2022-01-01                 51.088802   51.515265
# 2022-02-01                 51.312031   51.815184
# 2022-03-01                 50.884939   51.536179
# 2022-04-01                 50.289301   51.683626
# 2022-05-01                 50.343665   52.788121

# %%
# Se visualizan las predicciones
df_predictions.plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
# Se imprimen las predicciones para 2024 en base a los estándares de la OMS
print('Estas son las predicciones de contaminación acústica para la entrada de 2024, según el varemo de la OMS:')
for col in df_predictions:
    if (df_predictions[col].loc['2024-01-01'] > 55.0) & (df_predictions[col].loc['2024-01-01'] < 60.0):
        print(f'- La contaminación de la zona de {col} causará molestias en las personas ({round(df_predictions[col].loc["2024-01-01"], 2)} dBA la mayoría del tiempo).')
    elif (df_predictions[col].loc['2024-01-01'] > 60.0) & (df_predictions[col].loc['2024-01-01'] < 65.0):
        print(f'- La contaminación de la zona de {col} causará molestias serias en las personas ({round(df_predictions[col].loc["2024-01-01"], 2)} dBA la mayoría del tiempo).')
    elif df_predictions[col].loc['2024-01-01'] > 65.0:
        print(f'- La contaminación de la zona de {col} producirá transtornos de comportamiento ({round(df_predictions[col].loc["2024-01-01"], 2)} dBA la mayoría del tiempo).')
    else:
        print(f'- La contaminación de la zona de {col} no será grave ({round(df_predictions[col].loc["2024-01-01"], 2)} dBA la mayoría del tiempo).')
# Out:
# Estas son las predicciones de contaminación acústica para la entrada de 2024, según el varemo de la OMS:
# - La contaminación de la zona de Alto Extremadura no será grave (54.55 dBA la mayoría del tiempo).
# - La contaminación de la zona de Avda de Moratalaz causará molestias en las personas (55.39 dBA la mayoría del tiempo).
# - La contaminación de la zona de Carlos V causará molestias serias en las personas (64.53 dBA la mayoría del tiempo).
# - La contaminación de la zona de Castellana causará molestias en las personas (57.43 dBA la mayoría del tiempo).
# - La contaminación de la zona de Cuatro Caminos causará molestias en las personas (59.01 dBA la mayoría del tiempo).
# - La contaminación de la zona de El Pardo no será grave (49.04 dBA la mayoría del tiempo).
# - La contaminación de la zona de Ensanche de Vallecas causará molestias en las personas (57.61 dBA la mayoría del tiempo).
# - La contaminación de la zona de Escuelas Aguirre causará molestias serias en las personas (61.12 dBA la mayoría del tiempo).
# - La contaminación de la zona de Farolillo no será grave (49.22 dBA la mayoría del tiempo).
# - La contaminación de la zona de Gregorio Marañón causará molestias serias en las personas (64.83 dBA la mayoría del tiempo).
# - La contaminación de la zona de Méndez Álvaro no será grave (47.42 dBA la mayoría del tiempo).
# - La contaminación de la zona de Paseo de Recoletos causará molestias serias en las personas (61.37 dBA la mayoría del tiempo).
# - La contaminación de la zona de Plaza Manuel Becerra causará molestias en las personas (59.06 dBA la mayoría del tiempo).
# - La contaminación de la zona de Sanchinarro no será grave (53.82 dBA la mayoría del tiempo).
# - La contaminación de la zona de Santa Eugenia producirá transtornos de comportamiento (67.84 dBA la mayoría del tiempo).
# - La contaminación de la zona de Urbanización Embajada II no será grave (51.11 dBA la mayoría del tiempo).
# - La contaminación de la zona de Villaverde no será grave (51.21 dBA la mayoría del tiempo).
